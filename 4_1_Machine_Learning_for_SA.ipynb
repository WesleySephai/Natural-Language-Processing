# %% [markdown]
# ## Twitter Sentiment Analysis

# %%
import nltk

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Dataset

# %%
from google.colab import drive

### You can get this file from the link: https://nlp.stanford.edu/projects/glove/
### Unzip it and upload any of the 50/ 100/ 200/ 300 dimensional .txt file on your drive
# Note the file path to point to your downloaded/ uploaded GloVe file

drive.mount('/content/drive')
glove_file_path = '/content/drive/MyDrive/rep_Python/NLP/Sentiment_Analysis/'   ### For COLAB

df = pd.read_csv(glove_file_path + 'training.1600000.processed.noemoticon.csv',
                 delimiter=',', encoding='ISO-8859-1')
df
# Out:
# Mounted at /content/drive
#          polarity of tweet   id of the tweet             date of the tweet  \
# 0                         0       1467810672  Mon Apr 06 22:19:49 PDT 2009
# 1                         0       1467810917  Mon Apr 06 22:19:53 PDT 2009
# 2                         0       1467811184  Mon Apr 06 22:19:57 PDT 2009
# 3                         0       1467811193  Mon Apr 06 22:19:57 PDT 2009
# 4                         0       1467811372  Mon Apr 06 22:20:00 PDT 2009
# ...                     ...              ...                           ...
# 1048567                   4       1960186342  Fri May 29 07:33:44 PDT 2009
# 1048568                   4       1960186409  Fri May 29 07:33:43 PDT 2009
# 1048569                   4       1960186429  Fri May 29 07:33:44 PDT 2009
# 1048570                   4       1960186445  Fri May 29 07:33:44 PDT 2009
# 1048571                   4       1960186607  Fri May 29 07:33:45 PDT 2009
#
#             query             user  \
# 0        NO_QUERY    scotthamilton
# 1        NO_QUERY         mattycus
# 2        NO_QUERY          ElleCTF
# 3        NO_QUERY           Karoli
# 4        NO_QUERY         joy_wolf
# ...           ...              ...
# 1048567  NO_QUERY  Madelinedugganx
# 1048568  NO_QUERY     OffRoad_Dude
# 1048569  NO_QUERY         Falchion
# 1048570  NO_QUERY   jonasobsessedx
# 1048571  NO_QUERY        sugababez
#
#                                         text of the tweet
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# ...                                                    ...
# 1048567           My GrandMa is making Dinenr with my Mum
# 1048568  Mid-morning snack time... A bowl of cheese noo...
# 1048569  @ShaDeLa same here  say it like from the Termi...
# 1048570             @DestinyHope92 im great thaanks  wbuu?
# 1048571               cant wait til her date this weekend
#
# [1048572 rows x 6 columns]

# %%
df.columns = ['Sentiment','id','date','query','user','text']
df.head()
# Out:
#    Sentiment          id                          date     query  \
# 0          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
#
#             user                                               text
# 0  scotthamilton  is upset that he can't update his Facebook by ...
# 1       mattycus  @Kenichan I dived many times for the ball. Man...
# 2        ElleCTF    my whole body feels itchy and like its on fire
# 3         Karoli  @nationwideclass no, it's not behaving at all....
# 4       joy_wolf                      @Kwesidei not the whole crew

# %%
df = df[['Sentiment','text']]

# %%
df.columns
# Out:
# Index(['Sentiment', 'text'], dtype='object')

# %%
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    799996
# 4    248576
# Name: count, dtype: int64

# %%
df['Sentiment'] = df['Sentiment'].replace({4:1})
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    799996
# 1    248576
# Name: count, dtype: int64

# %% [markdown]
# * 0 represent Negative sentiment
# * 1 represents Positive sentiment

# %%
df.isna().sum()
# Out:
# Sentiment    0
# text         0
# dtype: int64

# %% [markdown]
# **Inference: The data is unbalanced therfore we will downsample the data to have same count for each sentiment**

# %% [markdown]
# *italicized text*## Downsampling the dataset

# %%
from sklearn.utils import resample

# %%
## majority class 0
df_majority = df[df['Sentiment']==0]
## minority class 1
df_minority = df[df['Sentiment']==1]

# %%
df_minority.shape
# Out:
# (248576, 2)

# %%
# downsample the majority class
df_majority_downsampled = resample(df_majority,
                                 replace=False,
                                 n_samples=len(df_minority),
                                 random_state=1234)

# %%
frames = [df_majority_downsampled, df_minority]

df = pd.concat(frames)
df.head()
# Out:
#         Sentiment                                               text
# 74567           0  Wow slept for almost 12hours. Sleepy me!! Uni ...
# 668722          0  gets bored with an idea too easily ... like tw...
# 286706          0  To my girls - sorry i've been a homebody latel...
# 632911          0  BK once again for the weekend...If it wasnt fo...
# 356735          0  @DonnieWahlberg Now why didn't you do that las...

# %%
df.Sentiment.value_counts()
# Out:
# Sentiment
# 0    248576
# 1    248576
# Name: count, dtype: int64

# %% [markdown]
# [link text](https://)## Data Preprocessing
#
# 1. removing stop words
# 2. removing punctuations
# 3. Stemmer
# 4. removing tags
# 5. removing special characters
# 6. lowercase conversion

# %%
## remove stopwords and punctuation marks
nltk.download('stopwords')
stuff_to_be_removed = list(stopwords.words('english'))+list(punctuation)
stemmer = LancasterStemmer()

corpus = df['text'].tolist()
print(len(corpus))
print(corpus[0])
# Out:
# 497152
# Wow slept for almost 12hours. Sleepy me!! Uni now, boo! I wanna stay home, drink tea and watch house...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('wordnet')
# %%time
final_corpus = []
final_corpus_joined = []
for i in df.index:

    text = re.sub('[^a-zA-Z]', ' ', df['text'][i])
    #Convert to lowercase
    text = text.lower()
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)

    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)

    ##Convert to list from string
    text = text.split()

    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text
            if not word in stuff_to_be_removed]
    text1 = " ".join(text)
    final_corpus.append(text)
    final_corpus_joined.append(text1)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# #### Storing the cleaned data seperately

# %%
data_cleaned = pd.DataFrame()
data_cleaned["text"] = final_corpus_joined
data_cleaned["Sentiment"] = df["Sentiment"].values

# %%
data_cleaned['Sentiment'].value_counts()
# Out:
# Sentiment
# 0    248576
# 1    248576
# Name: count, dtype: int64

# %%
data_cleaned.head()
# Out:
#                                                 text  Sentiment
# 0  wow slept almost hour sleepy uni boo wanna sta...          0
# 1                 get bored idea easily like twitter          0
# 2  girl sorry homebody lately dont feel well does...          0
# 3                     bk weekend wasnt puppy stay as          0
# 4                  donniewahlberg last night atlanta          0

# %% [markdown]
# ## EDA

# %%
data_eda = pd.DataFrame()
data_eda['text'] = final_corpus
data_eda['Sentiment'] = df["Sentiment"].values
data_eda.head()
# Out:
#                                                 text  Sentiment
# 0  [wow, slept, almost, hour, sleepy, uni, boo, w...          0
# 1          [get, bored, idea, easily, like, twitter]          0
# 2  [girl, sorry, homebody, lately, dont, feel, we...          0
# 3              [bk, weekend, wasnt, puppy, stay, as]          0
# 4             [donniewahlberg, last, night, atlanta]          0

# %%
# Storing positive data seperately
positive = data_eda[data_eda['Sentiment'] == 1]
positive_list = positive['text'].tolist()

# Storing negative data seperately

negative = data_eda[data_eda['Sentiment'] == 0]
negative_list = negative['text'].tolist()

# %%
positive_all = " ".join([word for sent in positive_list for word in sent ])
negative_all = " ".join([word for sent in negative_list for word in sent ])

# %% [markdown]
# #### Word Cloud Positive data

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(positive_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("Positive")
plt.show()

# %% [markdown]
# #### Word CLoud Negative data

# %%
from wordcloud import WordCloud
WordCloud()
wordcloud = WordCloud(width=2000,
                      height=1000,
                      background_color='#F2EDD7FF',
                      max_words = 100).generate(negative_all)

plt.figure(figsize=(20,30))
plt.imshow(wordcloud)
plt.title("negative")
plt.show()

# %% [markdown]
# **Inference:**
# * Positive data has words like Thank, love , LOL, Haha ets
# * Negative data has words like work, sad, tired, suck sorry <br>
# Some of the words are still common in both such as Lol, quot

# %% [markdown]
# #### One word count

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    return(dic)
count_corpus = get_count(positive_list)

# %%
count_corpus
# Out:
# {'love': 14982,
#  'health': 139,
#  'uandpets': 6,
#  'u': 12448,
#  'guy': 3483,
#  'r': 1874,
#  'best': 3431,
#  'im': 6434,
#  'meeting': 662,
#  'one': 8907,
#  'besties': 40,
#  'tonight': 3642,
#  'cant': 1515,
#  'wait': 4036,
#  'girl': 2895,
#  'talk': 1287,
#  'darealsunisakim': 3,
#  'thanks': 11403,
#  'twitter': 7196,
#  'add': 770,
#  'sunisa': 1,
#  'got': 8267,
#  'meet': 1108,
#  'hin': 5,
#  'show': 2899,
#  'dc': 143,
#  'area': 193,
#  'sweetheart': 105,
#  'sick': 486,
#  'really': 5887,
#  'cheap': 146,
#  'hurt': 370,
#  'much': 5265,
#  'eat': 1078,
#  'real': 1229,
#  'food': 1170,
#  'plus': 394,
#  'friend': 4320,
#  'make': 5340,
#  'soup': 177,
#  'lovesbrooklyn': 2,
#  'effect': 131,
#  'everyone': 3105,
#  'productoffear': 1,
#  'tell': 1916,
#  'burst': 24,
#  'laughing': 254,
#  'loud': 172,
#  'making': 1353,
#  'come': 4094,
#  'sulk': 5,
#  'keith': 40,
#  'hill': 280,
#  'thans': 1,
#  'response': 141,
#  'ihad': 3,
#  'already': 1667,
#  'find': 1614,
#  'answer': 402,
#  'keepinupwkris': 14,
#  'jealous': 354,
#  'hope': 6486,
#  'great': 8328,
#  'time': 10718,
#  'vega': 306,
#  'like': 12013,
#  'acm': 3,
#  'tommcfly': 570,
#  'ah': 976,
#  'congrats': 967,
#  'mr': 704,
#  'fletcher': 18,
#  'finally': 2434,
#  'joining': 105,
#  'e': 1137,
#  'voip': 7,
#  'responded': 30,
#  'stupid': 354,
#  'cat': 553,
#  'helping': 233,
#  'type': 285,
#  'forgive': 60,
#  'error': 62,
#  'crazy': 909,
#  'day': 19789,
#  'school': 2639,
#  'hour': 2500,
#  'straiiight': 1,
#  'watch': 2565,
#  'spencerpratt': 38,
#  'told': 585,
#  'ha': 1458,
#  'happy': 8155,
#  'birthday': 2343,
#  'jb': 137,
#  'naughtyhaughty': 3,
#  'forget': 548,
#  'two': 1540,
#  'half': 768,
#  'men': 372,
#  'nileyjileyluver': 1,
#  'haha': 6390,
#  'worry': 794,
#  'get': 11490,
#  'hang': 496,
#  'soundwav': 1,
#  'least': 1241,
#  'feeling': 1439,
#  'lost': 678,
#  'may': 1777,
#  'cause': 737,
#  'many': 1276,
#  'later': 2009,
#  'usual': 266,
#  'night': 8045,
#  'addicting': 59,
#  'lutheranlucciol': 1,
#  'sure': 2907,
#  'dm': 430,
#  'post': 1338,
#  'link': 922,
#  'video': 1692,
#  'lt': 3335,
#  'lol': 10741,
#  'gt': 1110,
#  'miss': 1844,
#  'better': 3898,
#  'permission': 21,
#  'blessing': 144,
#  'first': 3004,
#  'added': 319,
#  'tweetie': 194,
#  'new': 7882,
#  'iphone': 619,
#  'michellardi': 1,
#  'know': 8451,
#  'think': 6485,
#  'globe': 28,
#  'yeah': 3888,
#  'sana': 17,
#  'gumaling': 1,
#  'na': 319,
#  'ko': 103,
#  'para': 27,
#  'alam': 6,
#  'din': 85,
#  'kung': 24,
#  'makakasama': 1,
#  'ako': 56,
#  'nicolerichie': 67,
#  'picture': 1324,
#  'sweet': 1882,
#  'catching': 223,
#  'email': 790,
#  'random': 405,
#  'bacn': 2,
#  'cutting': 61,
#  'early': 1480,
#  'pm': 759,
#  'dinner': 1275,
#  'lauraw': 1,
#  'dancing': 321,
#  'around': 1515,
#  'room': 868,
#  'pjs': 28,
#  'jamming': 35,
#  'ipod': 413,
#  'getting': 3385,
#  'dizzy': 13,
#  'well': 7521,
#  'asked': 310,
#  'place': 1170,
#  'peep': 317,
#  'contest': 178,
#  'voting': 86,
#  'anyways': 240,
#  'going': 9424,
#  'bed': 3518,
#  'goodnight': 1521,
#  'dream': 1184,
#  'http': 14800,
#  'twitpic': 4101,
#  'com': 11017,
#  'littlelumen': 2,
#  'walking': 296,
#  'put': 1346,
#  'deposit': 10,
#  'tomorrow': 4485,
#  'followinq': 1,
#  'dachesterfrench': 3,
#  'shud': 55,
#  'tha': 172,
#  'lordpov': 1,
#  'meant': 393,
#  'back': 7359,
#  'quot': 14567,
#  'twittering': 322,
#  'toilet': 56,
#  'cubicle': 13,
#  'somewhere': 244,
#  'aw': 431,
#  'holding': 99,
#  'puppy': 228,
#  'mine': 1043,
#  'cutie': 94,
#  'ijohn': 1,
#  'kitteh': 10,
#  'sleepin': 28,
#  'crotch': 4,
#  'prof': 36,
#  'dramabeats': 9,
#  'agreed': 144,
#  'reaching': 28,
#  'amritsar': 1,
#  'bus': 366,
#  'wagah': 1,
#  'border': 34,
#  'bkite': 33,
#  'fuj': 1,
#  'albinla': 1,
#  'thinking': 1155,
#  'let': 3199,
#  'interview': 417,
#  'famous': 206,
#  'super': 871,
#  'star': 1145,
#  'spend': 362,
#  'family': 1319,
#  'tired': 1401,
#  'gonna': 3149,
#  'didnt': 507,
#  'effing': 89,
#  'throat': 80,
#  'hurting': 37,
#  'ooooohh': 2,
#  'craving': 108,
#  'pina': 14,
#  'colada': 5,
#  'banana': 158,
#  'slushie': 2,
#  'deon': 14,
#  'upload': 189,
#  'di': 103,
#  'indowebster': 1,
#  'dong': 36,
#  'banggggg': 1,
#  'wisdomous': 1,
#  'welcome': 2327,
#  'glad': 2655,
#  'enjoyed': 517,
#  'hawaii': 74,
#  'shellz': 2,
#  'hahaha': 1440,
#  'omg': 1313,
#  'wer': 12,
#  'laughin': 9,
#  'hook': 92,
#  'cuz': 469,
#  'da': 507,
#  'rolll': 1,
#  'ryt': 13,
#  'sheldawg': 1,
#  'sickwiththepen': 2,
#  'awww': 634,
#  'pookie': 7,
#  'feel': 3142,
#  'pray': 213,
#  'bag': 306,
#  'nurse': 44,
#  'yay': 3130,
#  'found': 1266,
#  'cuddle': 78,
#  'buddy': 312,
#  'met': 439,
#  'snob': 13,
#  'bad': 1800,
#  'life': 2805,
#  'go': 9178,
#  'across': 162,
#  'universe': 78,
#  'sleep': 3374,
#  'rehearsal': 83,
#  'annabellee': 1,
#  'dry': 114,
#  'potato': 108,
#  'huh': 339,
#  'jonathanrknight': 282,
#  'hi': 2402,
#  'jon': 179,
#  'hear': 1451,
#  'see': 7948,
#  'cruise': 133,
#  'cannot': 251,
#  'knight': 126,
#  'loved': 957,
#  'long': 2563,
#  'conversation': 198,
#  'mom': 2244,
#  'phone': 1295,
#  'suitelifeofkell': 6,
#  'yayyy': 96,
#  'requested': 17,
#  'herrr': 5,
#  'say': 3848,
#  'practicing': 42,
#  'line': 481,
#  'mannerism': 1,
#  'voice': 423,
#  'upcoming': 68,
#  'feature': 161,
#  'shoot': 328,
#  'probably': 928,
#  'driving': 379,
#  'brock': 6,
#  'read': 1581,
#  'moon': 257,
#  'rd': 262,
#  'enough': 958,
#  'twilight': 360,
#  'series': 268,
#  'today': 9627,
#  'month': 944,
#  'anniversary': 166,
#  'sooooooo': 38,
#  'diana': 53,
#  'dont': 1694,
#  'even': 2145,
#  'tar': 11,
#  'heel': 67,
#  'ncaa': 7,
#  'woot': 373,
#  'bored': 734,
#  'stevecla': 3,
#  'wallpaper': 55,
#  'red': 652,
#  'square': 74,
#  'asking': 296,
#  'pope': 14,
#  'mello': 3,
#  'noticed': 161,
#  'bb': 167,
#  'tryna': 51,
#  'inspired': 138,
#  'thats': 1604,
#  'kourtneykardash': 29,
#  'workout': 203,
#  'ladygaga': 39,
#  'ur': 2496,
#  'hot': 1400,
#  'as': 578,
#  'austin': 98,
#  'annnd': 10,
#  'bob': 125,
#  'purple': 145,
#  'went': 1680,
#  'royal': 50,
#  'color': 239,
#  'way': 4106,
#  'quotablebuffy': 4,
#  'bunch': 234,
#  'buffy': 34,
#  'song': 3007,
#  'faves': 52,
#  'vivian': 3,
#  'nerf': 4,
#  'herder': 2,
#  'faith': 127,
#  'spike': 29,
#  'body': 294,
#  'devunity': 1,
#  'check': 2009,
#  'morning': 7738,
#  'tweetland': 5,
#  'ahead': 357,
#  'uploading': 172,
#  'friendster': 47,
#  'ash': 102,
#  'ct': 57,
#  'pic': 2014,
#  'p': 2916,
#  'noodlebox': 1,
#  'amanda': 128,
#  'una': 20,
#  'avion': 3,
#  'sorrry': 3,
#  'different': 425,
#  'thing': 4099,
#  'kevin': 138,
#  'jonas': 495,
#  'girlfriend': 194,
#  'fuzeb': 1,
#  'serious': 237,
#  'singing': 389,
#  'whoa': 131,
#  'hehe': 1340,
#  'lsd': 2,
#  'maybe': 2183,
#  'j': 865,
#  'k': 1133,
#  'lolol': 52,
#  'loving': 802,
#  'apothecaryjeri': 5,
#  'sicilian': 4,
#  'damn': 770,
#  'pizza': 377,
#  'planet': 116,
#  'chocolate': 658,
#  'milk': 231,
#  'gf': 84,
#  'sutter': 2,
#  'creek': 31,
#  'tour': 514,
#  'old': 1815,
#  'bodycoach': 1,
#  'look': 4164,
#  'cho': 25,
#  'personally': 90,
#  'strawberry': 193,
#  'become': 219,
#  'coach': 75,
#  'soon': 2963,
#  'little': 2668,
#  'fish': 206,
#  'guess': 1494,
#  'live': 1605,
#  'side': 533,
#  'earth': 228,
#  'east': 124,
#  'mesa': 10,
#  'losiento': 1,
#  'paula': 46,
#  'paige': 33,
#  'apart': 108,
#  'sore': 141,
#  'tryout': 42,
#  'failed': 63,
#  'physic': 53,
#  'test': 511,
#  'homo': 18,
#  'keeen': 1,
#  'holiday': 729,
#  'observed': 6,
#  'update': 1068,
#  'alexa': 25,
#  'website': 495,
#  'tinyurl': 1982,
#  'c': 1608,
#  'gzf': 1,
#  'seems': 618,
#  'improving': 25,
#  'leiabox': 2,
#  'totally': 1042,
#  'geeking': 5,
#  'right': 3945,
#  'theragingocean': 2,
#  'bonjour': 29,
#  'spacecowboy': 1,
#  'wish': 2123,
#  'either': 581,
#  'work': 7097,
#  'kid': 1299,
#  'whenever': 124,
#  'want': 4269,
#  'wherever': 48,
#  'rebecca': 52,
#  'brother': 799,
#  'quite': 879,
#  'weird': 467,
#  'drdrew': 3,
#  'give': 1685,
#  'hug': 697,
#  'cookie': 116,
#  'hey': 4421,
#  'take': 2895,
#  'care': 861,
#  'rundown': 3,
#  'wrote': 232,
#  'wall': 212,
#  'correct': 122,
#  'poor': 232,
#  'spelling': 85,
#  'highlighter': 2,
#  'wash': 129,
#  'hardcore': 63,
#  'good': 20273,
#  'tech': 138,
#  'clubzone': 2,
#  'sushi': 161,
#  'mattgalloway': 2,
#  'carlyrush': 1,
#  'suggesting': 10,
#  'bro': 369,
#  'rock': 1221,
#  'jeffswarens': 1,
#  'depends': 123,
#  'version': 364,
#  'thought': 1943,
#  'speak': 292,
#  'ashley': 139,
#  'hand': 654,
#  'still': 4504,
#  'pretty': 2420,
#  'weak': 56,
#  'punch': 63,
#  'anyone': 1035,
#  'yet': 1479,
#  'turn': 563,
#  'knob': 4,
#  'doesnt': 187,
#  'honey': 251,
#  'lurker': 7,
#  'interesting': 804,
#  'saravananp': 2,
#  'b': 1940,
#  'north': 164,
#  'need': 4907,
#  'decide': 152,
#  'aaru': 1,
#  'hithavaru': 1,
#  'ninage': 1,
#  'ee': 34,
#  'moovarolage': 1,
#  'vote': 385,
#  'trstfndbby': 1,
#  'um': 220,
#  'bought': 768,
#  'shit': 614,
#  'korean': 47,
#  'oach': 1,
#  'highest': 25,
#  'quality': 189,
#  'baby': 1655,
#  'paid': 204,
#  'extra': 290,
#  'tag': 112,
#  'sewed': 4,
#  'eating': 1133,
#  'ice': 608,
#  'cream': 545,
#  'topping': 19,
#  'iamdiddy': 129,
#  'telling': 194,
#  'finished': 1328,
#  'crunch': 42,
#  'step': 277,
#  'diddy': 49,
#  'yvonne': 10,
#  'daaang': 1,
#  'possible': 252,
#  'lauruy': 1,
#  'west': 176,
#  'mostly': 169,
#  'san': 189,
#  'jose': 33,
#  'francisco': 27,
#  'nikki': 68,
#  'working': 1891,
#  'bike': 347,
#  'trying': 1427,
#  'recover': 23,
#  'knee': 85,
#  'injury': 22,
#  'marymayblood': 1,
#  'would': 4224,
#  'help': 1859,
#  'unpack': 8,
#  'sat': 329,
#  'afternoon': 785,
#  'shenagians': 1,
#  'team': 539,
#  'awesome': 4576,
#  'listening': 1726,
#  'music': 1956,
#  'chilling': 193,
#  'regret': 64,
#  'done': 2614,
#  'till': 979,
#  'kick': 341,
#  'study': 433,
#  'amp': 8014,
#  'grow': 141,
#  'rich': 114,
#  'wow': 2135,
#  'amazing': 2739,
#  'timeless': 11,
#  'law': 222,
#  'attraction': 17,
#  'program': 127,
#  'bittenbybooks': 4,
#  'oh': 5485,
#  'week': 4072,
#  'though': 2965,
#  'chris': 325,
#  'home': 5068,
#  'summer': 1248,
#  'davidgideon': 2,
#  'ish': 165,
#  'therealjspace': 2,
#  'tweet': 3721,
#  'drinking': 516,
#  'anne': 67,
#  'kay': 105,
#  'determined': 46,
#  'baseball': 110,
#  'year': 2252,
#  'since': 1066,
#  'watched': 883,
#  'sport': 162,
#  'interested': 249,
#  'game': 1663,
#  'beycah': 1,
#  'becca': 25,
#  'missnappyboy': 1,
#  'ohhh': 155,
#  'nkow': 1,
#  'lexington': 5,
#  'ky': 39,
#  'rite': 78,
#  'next': 3052,
#  'seen': 913,
#  'preview': 56,
#  'movie': 2856,
#  'obsessed': 108,
#  'w': 1914,
#  'beyonce': 50,
#  'broad': 13,
#  'nut': 138,
#  'easy': 578,
#  'rider': 34,
#  'fall': 401,
#  'asleep': 407,
#  'miketomalaris': 1,
#  'excited': 2146,
#  'broadcast': 39,
#  'paris': 161,
#  'roubaix': 1,
#  'moment': 553,
#  'belliestobabies': 1,
#  'people': 3369,
#  'survive': 67,
#  'winter': 138,
#  'without': 698,
#  'jungle': 31,
#  'gym': 497,
#  'jaredleto': 23,
#  'started': 684,
#  'last': 4371,
#  'holidayholiday': 1,
#  'watchin': 258,
#  'greek': 84,
#  'knighty': 8,
#  'medium': 269,
#  'design': 395,
#  'client': 227,
#  'profile': 422,
#  'lame': 181,
#  'stalk': 57,
#  'sexy': 374,
#  'lou': 49,
#  'aww': 944,
#  'another': 2027,
#  'nitey': 15,
#  'nite': 862,
#  'ahh': 480,
#  'kinda': 764,
#  'nervous': 138,
#  'til': 489,
#  'planning': 317,
#  'whatever': 401,
#  'happier': 87,
#  'hopin': 17,
#  'fb': 450,
#  'store': 448,
#  'missvic': 1,
#  'mean': 1589,
#  'jimmyeatworld': 5,
#  'www': 2017,
#  'deezer': 3,
#  'track': 370,
#  'urbanthai': 1,
#  'thank': 5126,
#  'pamfr': 1,
#  'pam': 40,
#  'yes': 4270,
#  'short': 613,
#  'struggle': 21,
#  'choice': 272,
#  'every': 1127,
#  'hmm': 513,
#  'lot': 2589,
#  'course': 1047,
#  'late': 1163,
#  'reading': 1041,
#  'guykawasaki': 14,
#  'follower': 1520,
#  'almost': 1090,
#  'larrycarroll': 1,
#  'nm': 35,
#  'screaming': 64,
#  'wondering': 357,
#  'freakin': 134,
#  'cooool': 18,
#  'renda': 1,
#  'nothing': 1343,
#  'wrong': 580,
#  'caring': 41,
#  'try': 2007,
#  'brissa': 1,
#  'lauren': 105,
#  'jbrotherlove': 1,
#  'story': 637,
#  'enbaldarlingg': 1,
#  'mirror': 61,
#  'looking': 2530,
#  'amandahesser': 1,
#  'neat': 76,
#  'god': 1688,
#  'overitnow': 1,
#  'apologize': 31,
#  'sharing': 311,
#  'spiritual': 27,
#  'general': 108,
#  'public': 153,
#  'leave': 743,
#  'ontario': 15,
#  'spoke': 50,
#  'fam': 296,
#  'japan': 73,
#  'via': 593,
#  'skype': 119,
#  'mo': 222,
#  'nephew': 111,
#  'growing': 115,
#  'lissym': 1,
#  'saw': 1585,
#  'written': 115,
#  'someone': 1326,
#  'spoken': 27,
#  'suck': 598,
#  'mcfly': 353,
#  'loser': 115,
#  'kacimaureen': 1,
#  'holy': 194,
#  'laundry': 176,
#  'woman': 525,
#  'hate': 912,
#  'trainer': 44,
#  'markhoppus': 80,
#  'fucking': 328,
#  'funny': 1638,
#  'setting': 192,
#  'touch': 337,
#  'officially': 302,
#  'nikhilnarayanan': 8,
#  'tvc': 2,
#  'yesterday': 1396,
#  'worked': 316,
#  'could': 2574,
#  'mannies': 1,
#  'peddies': 1,
#  'shut': 208,
#  'fat': 188,
#  'face': 809,
#  'magopus': 1,
#  'ever': 1918,
#  'run': 929,
#  'idea': 1230,
#  'nominating': 1,
#  'beer': 488,
#  'monday': 1481,
#  'never': 2086,
#  'always': 2594,
#  'hopeinhell': 7,
#  'usually': 261,
#  'follows': 88,
#  'special': 606,
#  'luck': 1763,
#  'rest': 866,
#  'cast': 90,
#  'tb': 60,
#  'something': 2138,
#  'leak': 13,
#  'land': 216,
#  'among': 34,
#  'johnhays': 1,
#  'agree': 670,
#  'entirely': 41,
#  'creative': 159,
#  'vibrant': 5,
#  'reason': 530,
#  'izzakizza': 1,
#  'nada': 23,
#  'holla': 89,
#  'hows': 238,
#  'mixtape': 23,
#  'coming': 1612,
#  'aussie': 128,
#  'ali': 87,
#  'yep': 644,
#  'easier': 226,
#  'point': 613,
#  'snarkattack': 8,
#  'freezer': 23,
#  'worthy': 46,
#  'amoir': 2,
#  'given': 160,
#  'scholarly': 4,
#  'attention': 152,
#  'suppose': 176,
#  'set': 662,
#  'eye': 694,
#  'jf': 14,
#  'cupcake': 201,
#  'purrplexa': 1,
#  'wonderful': 1114,
#  'favor': 71,
#  'using': 551,
#  'entire': 145,
#  'english': 476,
#  'language': 132,
#  'use': 1372,
#  'expletive': 2,
#  'mynameisgerard': 1,
#  'saying': 513,
#  'walk': 706,
#  'flippin': 17,
#  'cold': 611,
#  'outside': 781,
#  'ago': 692,
#  'sunny': 864,
#  'raining': 319,
#  'snowing': 15,
#  'sisterpatterson': 1,
#  'ate': 323,
#  'raw': 47,
#  'dough': 30,
#  'tub': 38,
#  'must': 1370,
#  'kindred': 8,
#  'spirit': 131,
#  'internet': 460,
#  'dirty': 126,
#  'nighty': 138,
#  'bloom': 17,
#  'tweetdeck': 234,
#  'facebook': 856,
#  'firestoned': 1,
#  'dude': 801,
#  'surprised': 180,
#  'tweeting': 562,
#  'nsastrasasmita': 1,
#  'figure': 397,
#  'llama': 8,
#  'malcolm': 2,
#  'megan': 72,
#  'fuck': 413,
#  'theatre': 64,
#  'kayotae': 1,
#  'martini': 30,
#  'city': 677,
#  'soo': 629,
#  'spring': 339,
#  'break': 675,
#  'watching': 4031,
#  'everyday': 203,
#  'pushplaynick': 3,
#  'grandpa': 43,
#  'chest': 36,
#  'beef': 60,
#  'george': 117,
#  'lopez': 28,
#  'rule': 253,
#  'katieporrello': 2,
#  'katie': 115,
#  'heading': 747,
#  'club': 413,
#  'stellar': 23,
#  'homey': 5,
#  'youtube': 823,
#  'v': 964,
#  'cle': 7,
#  'pjsras': 1,
#  'flower': 266,
#  'gone': 563,
#  'peter': 95,
#  'paul': 220,
#  'mary': 144,
#  'fav': 297,
#  'def': 242,
#  'shhhhhhhhhh': 1,
#  'posting': 179,
#  'photo': 1099,
#  'hit': 759,
#  'count': 276,
#  'china': 86,
#  'view': 301,
#  'alone': 317,
#  'came': 810,
#  'appreciate': 456,
#  'lonelybob': 5,
#  'everywhere': 149,
#  'provided': 21,
#  'broadband': 17,
#  'kiddin': 21,
#  'callin': 22,
#  'infinitarchitek': 1,
#  'stee': 1,
#  'hash': 29,
#  'bash': 25,
#  'anyway': 748,
#  'loltothepower': 1,
#  'correction': 48,
#  'badass': 41,
#  'fringe': 40,
#  'procoder': 3,
#  'hmmm': 363,
#  'upto': 22,
#  'ninasplayground': 3,
#  'christmas': 81,
#  'bn': 16,
#  'fun': 5754,
#  'caught': 230,
#  'yrold': 3,
#  'cheating': 22,
#  'reflection': 19,
#  'tv': 1000,
#  'hair': 1148,
#  'blue': 492,
#  'wendy': 44,
#  'bowser': 2,
#  'kind': 940,
#  'word': 1158,
#  'stressing': 14,
#  'math': 318,
#  'uhhh': 17,
#  'mintcool': 1,
#  'uh': 198,
#  'designated': 8,
#  'driver': 119,
#  'pch': 4,
#  'empressyen': 1,
#  'whatcha': 34,
#  'chucklin': 1,
#  'bout': 583,
#  'm': 237,
#  'yen': 13,
#  'ijustine': 34,
#  'augustography': 1,
#  'climbing': 39,
#  'sining': 2,
#  'unc': 15,
#  'prepare': 75,
#  'g': 1200,
#  'keyannaaa': 1,
#  'include': 55,
#  'magic': 242,
#  'fountain': 30,
#  'trip': 866,
#  'boring': 328,
#  'trusty': 6,
#  'book': 1447,
#  'anastasia': 7,
#  'laptop': 364,
#  'ff': 501,
#  'top': 662,
#  'buzzing': 13,
#  'sietar': 1,
#  'pattidigh': 8,
#  'pushing': 51,
#  'boundary': 24,
#  'boy': 1454,
#  'money': 687,
#  'manual': 24,
#  'yoshigi': 1,
#  'terrible': 86,
#  'neck': 79,
#  'ache': 47,
#  'chair': 91,
#  'waiting': 1281,
#  'swopper': 1,
#  'arrive': 103,
#  'juneaurock': 1,
#  'hellz': 8,
#  'definitely': 800,
#  'downloading': 157,
#  'jz': 10,
#  'stinkin': 14,
#  'cute': 1730,
#  'lyndeeezy': 1,
#  'hahah': 374,
#  'blog': 1420,
#  'nice': 5630,
#  'recent': 64,
#  'popular': 98,
#  'listed': 34,
#  'together': 640,
#  'michaelgrainger': 46,
#  'common': 96,
#  'ben': 185,
#  'mayer': 44,
#  ...}

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
count_corpus
# Out:
#                word  count
# 484            good  20273
# 84              day  19789
# 0              love  14982
# 180            http  14800
# 195            quot  14567
# ...             ...    ...
# 80783          gaza      1
# 80781     kimbeaver      1
# 80780    yegbikervr      1
# 80779      yegbiker      1
# 170651  terminiator      1
#
# [170652 rows x 2 columns]

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in positive data')
plt.show()

# %%
def get_count(data):
    dic = {}
    for i in data:
        for j in i:
            if j not in dic:
                dic[j]=1
            else:
                dic[j]+=1

    #dic = dict(sorted(dic.items() , key = lambda x:x[1],reverse=True))
    return(dic)
count_corpus = get_count(negative_list)

# %%
count_corpus = pd.DataFrame({"word":count_corpus.keys(),"count":count_corpus.values()})
count_corpus = count_corpus.sort_values(by = "count", ascending = False)

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x = count_corpus["word"][:20], y = count_corpus["count"][:20])
plt.title('one words in negative data')
plt.show()

# %% [markdown]
# **Inference**
# * Positive data has words like good, day, thanks, great, happy
# * Negative data has words like work, miss, sad etc

# %% [markdown]
# ## Classification
# ### Naive bayes for sentiment analysis

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_list)
negative_tokens_for_model = get_tweets_for_model(negative_list)

# %%
positive_tokens_for_model
# Out:
# <generator object get_tweets_for_model at 0x7998501be7a0>

# %%
import random

positive_dataset = [(review_dict, "Positive")
                     for review_dict in positive_tokens_for_model]

negative_dataset = [(review_dict, "Negative")
                     for review_dict in negative_tokens_for_model]
dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:333091]
test_data = dataset[333091:]

# %%
train_data[1]
# Out:
# ({'bobbyllew': True,
#   'mention': True,
#   'understanding': True,
#   'biology': True,
#   'many': True,
#   'area': True},
#  'Positive')

# %%
dataset
# Out:
# [({'getting': True,
#    'ready': True,
#    'shoot': True,
#    'http': True,
#    'plurk': True,
#    'com': True,
#    'p': True,
#    'swxfm': True},
#   'Positive'),
#  ({'bobbyllew': True,
#    'mention': True,
#    'understanding': True,
#    'biology': True,
#    'many': True,
#    'area': True},
#   'Positive'),
#  ({'sorry': True,
#    'yukkies': True,
#    'im': True,
#    'working': True,
#    'wont': True,
#    'new': True,
#    'episode': True,
#    'maybe': True,
#    'next': True,
#    'one': True,
#    'message': True,
#    'matthardybrand': True,
#    'tell': True,
#    'want': True,
#    'yuk': True,
#    'lol': True},
#   'Negative'),
#  ({'smophberry': True,
#    'omg': True,
#    'know': True,
#    'argh': True,
#    'im': True,
#    'sooooooooo': True,
#    'excited': True,
#    'thats': True,
#    'like': True,
#    'th': True,
#    'time': True,
#    'ive': True,
#    'said': True,
#    'today': True,
#    'haha': True},
#   'Positive'),
#  ({'englishrose': True, 'thats': True, 'awful': True}, 'Negative'),
#  ({'meldrum': True,
#    'awa': True,
#    'put': True,
#    'aiden': True,
#    'bed': True,
#    'give': True,
#    'dad': True,
#    'quick': True,
#    'call': True,
#    'free': True,
#    'min': True},
#   'Positive'),
#  ({'woke': True,
#    'extremely': True,
#    'long': True,
#    'nap': True,
#    'med': True,
#    'working': True,
#    'pain': True},
#   'Negative'),
#  ({'aie': True, 'winema': True, 'horde': True}, 'Positive'),
#  ({'vagelisv': True,
#    'laptop': True,
#    'last': True,
#    'night': True,
#    'month': True,
#    'old': True,
#    'nothing': True,
#    'wrong': True,
#    'w': True,
#    'battery': True,
#    'dying': True},
#   'Positive'),
#  ({'angee': True,
#    'know': True,
#    'lucky': True,
#    'get': True,
#    'spend': True,
#    'time': True,
#    'better': True,
#    'appreciate': True},
#   'Positive'),
#  ({'good': True,
#    'morning': True,
#    'everyone': True,
#    'sun': True,
#    'shinning': True,
#    'hope': True,
#    'better': True,
#    'day': True,
#    'yesterday': True},
#   'Positive'),
#  ({'enjoying': True,
#    'tread': True,
#    'various': True,
#    'forum': True,
#    'darksiders': True,
#    'classy': True,
#    'comment': True},
#   'Positive'),
#  ({'http': True,
#    'tinyurl': True,
#    'com': True,
#    'stackus': True,
#    'video': True,
#    'take': True,
#    'look': True,
#    'excuse': True,
#    'voice': True,
#    'though': True,
#    'feeling': True,
#    'bad': True,
#    'today': True,
#    'oh': True,
#    'well': True,
#    'vids': True},
#   'Negative'),
#  ({'keisheraonline': True,
#    'awww': True,
#    'reallyyy': True,
#    'lol': True,
#    'told': True},
#   'Negative'),
#  ({'curmudgeonlaine': True,
#    'omg': True,
#    'yes': True,
#    'sorry': True,
#    'deactivating': True,
#    'facebook': True,
#    'w': True,
#    'announcing': True,
#    'duty': True,
#    'call': True,
#    'like': True,
#    'bar': True,
#    'exam': True},
#   'Positive'),
#  ({'kind': True, 'monday': True, 'market': True, 'every': True, 'month': True},
#   'Positive'),
#  ({'jerridkruse': True,
#    'ok': True,
#    'kool': True,
#    'unless': True,
#    'agree': True,
#    'alex': True,
#    'guy': True,
#    'thriving': True,
#    'ivory': True,
#    'suck': True},
#   'Negative'),
#  ({'sila': True,
#    'lol': True,
#    'quot': True,
#    'plug': True,
#    'chug': True,
#    'sound': True,
#    'like': True,
#    'night': True,
#    'math': True},
#   'Positive'),
#  ({'maybe': True,
#    'punishment': True,
#    'horrible': True,
#    'people': True,
#    'become': True,
#    'one': True},
#   'Negative'),
#  ({'shloo': True, 'hello': True, 'cutie': True}, 'Positive'),
#  ({'school': True,
#    'home': True,
#    'clean': True,
#    'hopefullyi': True,
#    'think': True,
#    'dress': True,
#    'shopping': True,
#    'hay': True,
#    'layy': True},
#   'Positive'),
#  ({'u': True, 'laserquest': True, 'came': True, 'th': True, 'overall': True},
#   'Positive'),
#  ({'back': True,
#    'neck': True,
#    'ache': True,
#    'soo': True,
#    'freaking': True,
#    'much': True,
#    'wait': True,
#    'weekend': True,
#    'staying': True,
#    'bed': True,
#    'allllll': True,
#    'day': True,
#    'damnit': True},
#   'Negative'),
#  ({'poppin': True, 'cherry': True, 'badass': True, 'right': True, 'guy': True},
#   'Positive'),
#  ({'supposed': True, 'studying': True}, 'Negative'),
#  ({'tweaked': True, 'tumblr': True, 'layout': True}, 'Positive'),
#  ({'http': True,
#    'piurl': True,
#    'com': True,
#    'xp': True,
#    'current': True,
#    'location': True,
#    'k': True,
#    'ge': True,
#    'dk': True,
#    'brewery': True},
#   'Positive'),
#  ({'counted': True,
#    'pro': True,
#    'amp': True,
#    'con': True,
#    'list': True,
#    'six': True,
#    'side': True},
#   'Negative'),
#  ({'bad': True,
#    'boy': True,
#    'tv': True,
#    'scene': True,
#    'smith': True,
#    'running': True,
#    'shirt': True,
#    'open': True,
#    'nice': True},
#   'Positive'),
#  ({'get': True,
#    'celebrate': True,
#    'intl': True,
#    'sushi': True,
#    'day': True,
#    'fun': True,
#    'watching': True,
#    'round': True,
#    'rock': True,
#    'express': True,
#    'amp': True,
#    'eating': True,
#    'ballparkfood': True,
#    'thirsty': True,
#    'thursday': True,
#    'offbeer': True},
#   'Negative'),
#  ({'tlwh': True,
#    'love': True,
#    'website': True,
#    'wonderful': True,
#    'amazing': True,
#    'time': True},
#   'Positive'),
#  ({'introspectre': True,
#    'hope': True,
#    'forecast': True,
#    'varies': True,
#    'depending': True,
#    'website': True,
#    'look': True,
#    'inevitably': True},
#   'Positive'),
#  ({'think': True, 'danny': True, 'really': True, 'great': True}, 'Positive'),
#  ({'alexajordan': True,
#    'omg': True,
#    'could': True,
#    'next': True,
#    'weekend': True},
#   'Positive'),
#  ({'experiencing': True,
#    'unique': True,
#    'winnipeg': True,
#    'tradition': True,
#    'known': True,
#    'quot': True,
#    'social': True,
#    'trying': True,
#    'pace': True},
#   'Positive'),
#  ({'early': True,
#    'work': True,
#    'first': True,
#    'day': True,
#    'summer': True,
#    'session': True},
#   'Negative'),
#  ({'huh': True, 'getting': True, 'bored': True, 'thing': True}, 'Negative'),
#  ({'mnowluck': True,
#    'chhama': True,
#    'home': True,
#    'n': True,
#    'u': True,
#    'know': True,
#    'internet': True,
#    'connection': True,
#    'like': True,
#    'keep': True,
#    'tweeting': True,
#    'b': True,
#    'back': True,
#    'soon': True},
#   'Positive'),
#  ({'track': True, 'time': True}, 'Positive'),
#  ({'sydney': True,
#    'landrover': True,
#    'station': True,
#    'wagon': True,
#    'ono': True,
#    'new': True,
#    'ad': True,
#    'received': True,
#    'posted': True,
#    'hcc': True,
#    'site': True,
#    'soon': True},
#   'Positive'),
#  ({'mondy': True}, 'Negative'),
#  ({'chalkface': True,
#    'happy': True,
#    'birthday': True,
#    'great': True,
#    'day': True},
#   'Positive'),
#  ({'sleeep': True,
#    'em': True,
#    'tomorrow': True,
#    'church': True,
#    'morning': True,
#    'picking': True,
#    'brother': True,
#    'around': True,
#    'ish': True,
#    'new': True,
#    'job': True,
#    'awww': True,
#    'cute': True,
#    'p': True},
#   'Positive'),
#  ({'cant': True,
#    'wait': True,
#    'weekend': True,
#    'maybe': True,
#    'filled': True,
#    'makeup': True,
#    'workshop': True,
#    'single': True,
#    'break': True},
#   'Negative'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'iv': True,
#    'u': True,
#    'love': True,
#    'babyyyy': True,
#    'amp': True,
#    'lucy': True},
#   'Positive'),
#  ({'marinnoarthur': True, 'eu': True, 'sou': True, 'php': True}, 'Positive'),
#  ({'donniewahlberg': True,
#    'know': True,
#    'always': True,
#    'u': True,
#    'fan': True,
#    'mind': True},
#   'Positive'),
#  ({'airofina': True,
#    'think': True,
#    'overloaded': True,
#    'terminator': True,
#    'trying': True,
#    'break': True,
#    'u': True},
#   'Negative'),
#  ({'lyriciss': True}, 'Negative'),
#  ({'got': True,
#    'shocking': True,
#    'news': True,
#    'early': True,
#    'morning': True,
#    'beby': True,
#    'heart': True,
#    'atack': True},
#   'Negative'),
#  ({'yyes': True,
#    'dad': True,
#    'promised': True,
#    'help': True,
#    'make': True,
#    'scone': True,
#    'diner': True},
#   'Positive'),
#  ({'yea': True, 'still': True, 'luck': True}, 'Negative'),
#  ({'sallyslytherin': True, 'right': True, 'clean': True, 'house': True},
#   'Negative'),
#  ({'donnieklang': True, 'hi': True, 'r': True, 'u': True, 'today': True},
#   'Positive'),
#  ({'silverahnia': True, 'ahhhh': True, 'wish': True, 'take': True, 'u': True},
#   'Negative'),
#  ({'jenjoyner': True, 'sorry': True, 'hear': True, 'uncle': True}, 'Negative'),
#  ({'sitting': True, 'traffic': True, 'without': True, 'ipod': True},
#   'Negative'),
#  ({'maureenoconnell': True,
#    'briton': True,
#    'lot': True,
#    'thing': True,
#    'sometimes': True,
#    'think': True,
#    'talent': True,
#    'rare': True,
#    'commodity': True},
#   'Negative'),
#  ({'amber': True,
#    'boyd': True,
#    'wrong': True,
#    'u': True,
#    'told': True,
#    'mine': True,
#    'already': True,
#    'tho': True,
#    'need': True,
#    'look': True,
#    'btw': True,
#    'line': True,
#    'ha': True,
#    'evil': True,
#    'laff': True},
#   'Negative'),
#  ({'update': True, 'status': True, 'twitter': True, 'cell': True}, 'Positive'),
#  ({'dating': True,
#    'oh': True,
#    'get': True,
#    'killed': True,
#    'something': True,
#    'big': True,
#    'mouthy': True,
#    'quot': True,
#    'long': True,
#    'kinda': True,
#    'girl': True},
#   'Positive'),
#  ({'gd': True,
#    'morning': True,
#    'swan': True,
#    'baby': True,
#    'born': True,
#    'tiny': True,
#    'fuzzy': True,
#    'yellow': True,
#    'body': True,
#    'soo': True,
#    'cute': True,
#    'stand': True},
#   'Positive'),
#  ({'etacar': True,
#    'law': True,
#    'order': True,
#    'fan': True,
#    'remember': True,
#    'detective': True,
#    'ben': True,
#    'suarato': True,
#    'named': True,
#    'son': True},
#   'Positive'),
#  ({'alicayaba': True,
#    'cuuute': True,
#    'hey': True,
#    'miss': True,
#    'na': True,
#    'seeing': True,
#    'girl': True,
#    'everyday': True},
#   'Negative'),
#  ({'found': True, 'today': True, 'legend': True}, 'Positive'),
#  ({'work': True, 'yet': True, 'jersey': True, 'tomorrow': True}, 'Positive'),
#  ({'working': True, 'sundayyy': True}, 'Negative'),
#  ({'eye': True,
#    'swollen': True,
#    'amp': True,
#    'streaming': True,
#    'throat': True,
#    'voice': True,
#    'croaky': True,
#    'breathe': True,
#    'congested': True,
#    'headache': True},
#   'Negative'),
#  ({'misskittymarie': True,
#    'ton': True,
#    'picture': True,
#    'yummmy': True,
#    'im': True,
#    'hungry': True},
#   'Positive'),
#  ({'ninamcfly': True,
#    'yeah': True,
#    'french': True,
#    'awful': True,
#    'hate': True,
#    'much': True,
#    'love': True,
#    'mcfly': True},
#   'Positive'),
#  ({'lilpsycho': True, 'face': True}, 'Negative'),
#  ({'rachelyeah': True, 'take': True, 'tissue': True}, 'Positive'),
#  ({'agent': True,
#    'maxine': True,
#    'found': True,
#    'good': True,
#    'background': True,
#    'use': True,
#    'yet': True,
#    'hate': True,
#    'one': True,
#    'gt': True,
#    'need': True,
#    'gaspard': True,
#    'lol': True},
#   'Negative'),
#  ({'jledwell': True,
#    'lisarex': True,
#    'megux': True,
#    'comforting': True,
#    'know': True,
#    'others': True,
#    'portfolio': True,
#    'hell': True,
#    'making': True,
#    'feel': True,
#    'like': True,
#    'suck': True},
#   'Negative'),
#  ({'started': True,
#    'lvl': True,
#    'ing': True,
#    'around': True,
#    'gold': True,
#    'today': True,
#    'grinding': True,
#    'day': True,
#    'broke': True},
#   'Positive'),
#  ({'bike': True,
#    'commuting': True,
#    'gym': True,
#    'morning': True,
#    'got': True,
#    'ride': True,
#    'road': True,
#    'typically': True,
#    'busy': True,
#    'ti': True,
#    'nice': True,
#    'pavement': True},
#   'Positive'),
#  ({'maaaan': True, 'hate': True, 'trying': True, 'erased': True}, 'Negative'),
#  ({'mcfly': True,
#    'one': True,
#    'day': True,
#    'ago': True,
#    'want': True,
#    'baaaaaaack': True},
#   'Negative'),
#  ({'fakerstephanier': True,
#    'steph': True,
#    'nick': True,
#    'rob': True,
#    'focused': True,
#    'new': True,
#    'moon': True,
#    'cannes': True,
#    'promoting': True,
#    'movie': True,
#    'none': True},
#   'Positive'),
#  ({'form': True,
#    'get': True,
#    'back': True,
#    'u': True,
#    'soon': True,
#    'x': True},
#   'Positive'),
#  ({'saved': True,
#    'old': True,
#    'lady': True,
#    'even': True,
#    'clock': True,
#    'far': True,
#    'today': True},
#   'Positive'),
#  ({'twisource': True,
#    'thought': True,
#    'new': True,
#    'moon': True,
#    'trailer': True,
#    'major': True,
#    'problem': True,
#    'see': True,
#    'alice': True,
#    'died': True,
#    'hair': True,
#    'nooo': True},
#   'Negative'),
#  ({'still': True, 'working': True, 'homework': True}, 'Negative'),
#  ({'bts': True, 'going': True, 'trendingggg': True}, 'Negative'),
#  ({'mahen': True, 'give': True, 'free': True}, 'Positive'),
#  ({'hour': True, 'left': True, 'ipod': True, 'touch': True}, 'Negative'),
#  ({'hipplepatel': True,
#    'jimangstadt': True,
#    'thanks': True,
#    'tip': True,
#    'cecheese': True,
#    'definite': True,
#    'headache': True,
#    'thinking': True,
#    'plymouth': True,
#    'center': True,
#    'swimming': True,
#    'pool': True,
#    'aquarium': True,
#    'close': True,
#    'second': True},
#   'Positive'),
#  ({'ooh': True,
#    'dad': True,
#    'phoned': True,
#    'coming': True,
#    'see': True,
#    'thursday': True,
#    'yay': True},
#   'Positive'),
#  ({'update': True,
#    'c': True,
#    'u': True,
#    'introduction': True,
#    'quot': True,
#    'hallo': True,
#    'mijn': True,
#    'naam': True,
#    'ma': True,
#    'followed': True,
#    'chorus': True,
#    'kid': True,
#    'haalllooooo': True,
#    'maaaas': True},
#   'Positive'),
#  ({'ken': True,
#    'windward': True,
#    'lol': True,
#    'well': True,
#    'die': True,
#    'skip': True,
#    'one': True,
#    'meal': True},
#   'Positive'),
#  ({'wishing': True, 'still': True, 'work': True}, 'Negative'),
#  ({'raaaiiiin': True, 'camping': True, 'fun': True}, 'Negative'),
#  ({'look': True,
#    'like': True,
#    'may': True,
#    'gout': True,
#    'figure': True,
#    'go': True,
#    'anywhere': True,
#    'live': True},
#   'Negative'),
#  ({'new': True,
#    'iphone': True,
#    'yay': True,
#    'restoring': True,
#    'backup': True,
#    'stupid': True,
#    'apple': True},
#   'Negative'),
#  ({'blue': True,
#    'cat': True,
#    'online': True,
#    'musicmonday': True,
#    'recommendation': True},
#   'Positive'),
#  ({'anyone': True,
#    'want': True,
#    'deliver': True,
#    'bowl': True,
#    'pho': True,
#    'sick': True,
#    'craving': True,
#    'noodle': True,
#    'soup': True},
#   'Negative'),
#  ({'hoping': True,
#    'today': True,
#    'better': True,
#    'yesterday': True,
#    'must': True,
#    'whatever': True,
#    'take': True,
#    'get': True,
#    'apt': True},
#   'Positive'),
#  ({'karenbirch': True,
#    'thank': True,
#    'best': True,
#    'parcel': True,
#    'ever': True,
#    'x': True},
#   'Positive'),
#  ({'jct': True, 'love': True, 'unknown': True}, 'Positive'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'p': True,
#    'dd': True,
#    'erdinger': True,
#    'yes': True,
#    'today': True},
#   'Positive'),
#  ({'nd': True,
#    'time': True,
#    'month': True,
#    'ruined': True,
#    'brand': True,
#    'new': True,
#    'garment': True,
#    'spilling': True,
#    'drop': True,
#    'oil': True,
#    'st': True,
#    'blue': True,
#    'dress': True,
#    'adorable': True,
#    'shirt': True},
#   'Negative'),
#  ({'isaponturo': True,
#    'yeah': True,
#    'live': True,
#    'small': True,
#    'town': True,
#    'lule': True,
#    'life': True,
#    'spain': True,
#    'think': True,
#    'know': True,
#    'even': True,
#    'exicted': True,
#    'poor': True},
#   'Negative'),
#  ({'new': True,
#    'version': True,
#    'care': True,
#    'bear': True,
#    'make': True,
#    'kind': True,
#    'sad': True,
#    'lovely': True,
#    'charm': True,
#    'original': True,
#    'one': True},
#   'Negative'),
#  ({'woo': True,
#    'finally': True,
#    'booked': True,
#    'flight': True,
#    'london': True,
#    'day': True,
#    'go': True},
#   'Positive'),
#  ({'tommcfly': True, 'oun': True, 'tom': True, 'ok': True, 'haha': True},
#   'Negative'),
#  ({'deserve': True,
#    'thiss': True,
#    'stuck': True,
#    'dryer': True,
#    'smell': True,
#    'like': True,
#    'pee': True,
#    'hair': True,
#    'salon': True,
#    'wanted': True,
#    'new': True,
#    'style': True},
#   'Negative'),
#  ({'super': True, 'tierd': True, 'want': True, 'exam': True}, 'Negative'),
#  ({'feel': True,
#    'like': True,
#    'watching': True,
#    'disney': True,
#    'movie': True,
#    'bad': True,
#    'dont': True,
#    'vcr': True,
#    'anymore': True},
#   'Negative'),
#  ({'idrvfast': True,
#    'sa': True,
#    'weeeet': True,
#    'background': True,
#    'except': True,
#    'cant': True,
#    'read': True,
#    'say': True},
#   'Negative'),
#  ({'lzmoakatude': True,
#    'f': True,
#    'ing': True,
#    'life': True,
#    'pleeaasse': True,
#    'love': True,
#    'u': True,
#    'miss': True},
#   'Negative'),
#  ({'today': True,
#    'good': True,
#    'day': True,
#    'rd': True,
#    'amp': True,
#    'th': True,
#    'tiny': True,
#    'triumph': True,
#    'lt': True,
#    'nine': True,
#    'month': True,
#    'iversary': True,
#    'memo': True,
#    'gtp': True,
#    'performance': True,
#    'feelin': True,
#    'hot': True,
#    'todayy': True},
#   'Positive'),
#  ({'hate': True,
#    'fact': True,
#    'sleeping': True,
#    'good': True,
#    'got': True,
#    'woken': True,
#    'kid': True,
#    'evidently': True,
#    'sleep': True,
#    'better': True,
#    'get': True},
#   'Negative'),
#  ({'eeshkapeesh': True,
#    'lol': True,
#    'probably': True,
#    'send': True,
#    'see': True,
#    'think': True,
#    'gonna': True,
#    'long': True,
#    'chapter': True,
#    'fluff': True},
#   'Positive'),
#  ({'ladyredcrest': True, 'seat': True, 'unfortunately': True, 'pit': True},
#   'Negative'),
#  ({'ddlovato': True,
#    'yes': True,
#    'plllleeeaassseeeee': True,
#    'best': True,
#    'friend': True},
#   'Positive'),
#  ({'lil': True,
#    'tim': True,
#    'hey': True,
#    'thanks': True,
#    'much': True,
#    'positive': True,
#    'feedback': True,
#    'spread': True,
#    'love': True},
#   'Positive'),
#  ({'theblowups': True, 'careful': True, 'dunk': True, 'long': True},
#   'Positive'),
#  ({'back': True, 'ga': True}, 'Positive'),
#  ({'donniewahlberg': True,
#    'llllllloooooooovvvvvvvvvvveeeeeeeeee': True,
#    'back': True,
#    'ya': True},
#   'Positive'),
#  ({'blah': True, 'monday': True, 'miss': True, 'baby': True, 'already': True},
#   'Negative'),
#  ({'lotioning': True,
#    'skin': True,
#    'day': True,
#    'beach': True,
#    'damn': True,
#    'wind': True,
#    'making': True,
#    'seem': True,
#    'hot': True,
#    'mmm': True,
#    'cripsy': True,
#    'brown': True,
#    'haha': True},
#   'Positive'),
#  ({'sharding': True,
#    'scaling': True,
#    'technique': True,
#    'covered': True,
#    'slide': True,
#    'minute': True,
#    'university': True},
#   'Positive'),
#  ({'xosandy': True, 'stupid': True, 'pig': True}, 'Negative'),
#  ({'dammit': True, 'im': True, 'bored': True}, 'Negative'),
#  ({'farrah': True,
#    'fawcett': True,
#    'passed': True,
#    'away': True,
#    'http': True,
#    'www': True,
#    'cnn': True,
#    'com': True,
#    'showbiz': True,
#    'tv': True,
#    'obit': True,
#    'index': True,
#    'html': True,
#    'spokesnwheels': True},
#   'Negative'),
#  ({'woke': True,
#    'today': True,
#    'toothache': True,
#    'hell': True,
#    'broke': True,
#    'called': True,
#    'dentist': True,
#    'here': True,
#    'f': True,
#    'ing': True,
#    'credit': True,
#    'financing': True,
#    'dental': True,
#    'work': True},
#   'Negative'),
#  ({'snack': True, 'study': True, 'boring': True}, 'Negative'),
#  ({'lapsedcannibal': True,
#    'almost': True,
#    'sound': True,
#    'like': True,
#    'could': True,
#    'title': True,
#    'new': True,
#    'comic': True,
#    'book': True,
#    'series': True},
#   'Positive'),
#  ({'fosterdad': True,
#    'ha': True,
#    'join': True,
#    'twitter': True,
#    'revolution': True,
#    'something': True,
#    'else': True,
#    'sure': True},
#   'Positive'),
#  ({'leti': True,
#    'men': True,
#    'take': True,
#    'back': True,
#    'better': True,
#    'get': True,
#    'win': True,
#    'weekend': True},
#   'Positive'),
#  ({'almost': True, 'home': True, 'mmm': True, 'good': True, 'day': True},
#   'Positive'),
#  ({'starhiphopts': True, 'know': True, 'friday': True}, 'Positive'),
#  ({'radishh': True,
#    'thing': True,
#    'happened': True,
#    'fucked': True,
#    'car': True},
#   'Negative'),
#  ({'big': True,
#    'smoke': True,
#    'tonight': True,
#    'work': True,
#    'doll': True,
#    'costume': True,
#    'packed': True,
#    'expo': True},
#   'Positive'),
#  ({'watchin': True,
#    'quot': True,
#    'cone': True,
#    'zone': True,
#    'miss': True,
#    'joel': True},
#   'Negative'),
#  ({'miss': True, 'shachar': True}, 'Negative'),
#  ({'krystlechow': True,
#    'think': True,
#    'point': True,
#    'would': True,
#    'set': True,
#    'filter': True,
#    'put': True,
#    'straight': True,
#    'e': True,
#    'mail': True,
#    'junk': True,
#    'trash': True,
#    'folder': True},
#   'Negative'),
#  ({'back': True,
#    'onmyd': True,
#    'grind': True,
#    'quot': True,
#    'locked': True,
#    'iamdiddy': True,
#    'would': True,
#    'say': True},
#   'Positive'),
#  ({'went': True,
#    'kickboxing': True,
#    'class': True,
#    'w': True,
#    'mommy': True,
#    'amp': True,
#    'sister': True,
#    'jillhiraizumi': True,
#    'eat': True,
#    'korean': True,
#    'food': True,
#    'dinner': True,
#    'totally': True,
#    'gained': True,
#    'sweated': True},
#   'Negative'),
#  ({'laid': True,
#    'head': True,
#    'sleep': True,
#    'wide': True,
#    'awake': True,
#    'ten': True,
#    'min': True,
#    'ill': True,
#    'tired': True,
#    'vicious': True,
#    'cycle': True,
#    'repeat': True,
#    'still': True,
#    'pimple': True},
#   'Negative'),
#  ({'oh': True,
#    'man': True,
#    'wanted': True,
#    'buy': True,
#    'ticket': True,
#    'lady': True,
#    'gaga': True,
#    'sold': True,
#    'whatever': True,
#    'happy': True,
#    'p': True,
#    'nk': True,
#    'november': True,
#    'th': True},
#   'Negative'),
#  ({'libraryy': True,
#    'attempting': True,
#    'research': True,
#    'paper': True,
#    'amp': True,
#    'really': True,
#    'getting': True,
#    'anywhere': True,
#    'final': True,
#    'due': True,
#    'tues': True,
#    'fml': True},
#   'Negative'),
#  ({'tell': True,
#    'day': True,
#    'going': True,
#    'fucking': True,
#    'suck': True,
#    'yay': True},
#   'Negative'),
#  ({'morning': True,
#    'start': True,
#    'day': True,
#    'one': True,
#    'lisavine': True,
#    'reedoh': True,
#    'marginatasnaily': True,
#    'sammi': True,
#    'jade': True,
#    'followfriday': True},
#   'Positive'),
#  ({'gearing': True,
#    'week': True,
#    'ahead': True,
#    'better': True,
#    'toss': True,
#    'efusjons': True,
#    'fridge': True,
#    'morning': True},
#   'Positive'),
#  ({'cathy': True,
#    'cochina': True,
#    'true': True,
#    'better': True,
#    'nothing': True},
#   'Positive'),
#  ({'made': True,
#    'follower': True,
#    'thank': True,
#    'much': True,
#    'hope': True,
#    'bring': True,
#    'board': True,
#    'thought': True,
#    'ebay': True},
#   'Positive'),
#  ({'oy': True, 'leg': True, 'hurt': True, 'running': True, 'treadmill': True},
#   'Negative'),
#  ({'laying': True,
#    'holcomb': True,
#    'garden': True,
#    'going': True,
#    'swimming': True,
#    'hrc': True,
#    'lovely': True,
#    'day': True},
#   'Positive'),
#  ({'class': True,
#    'saturday': True,
#    'believe': True,
#    'shii': True,
#    'love': True},
#   'Positive'),
#  ({'welpje': True, 'awh': True, 'suck': True, 'huggles': True}, 'Negative'),
#  ({'found': True,
#    'tiny': True,
#    'kitten': True,
#    'walking': True,
#    'tonight': True,
#    'keep': True,
#    'molly': True,
#    'freaked': True,
#    'sooooo': True,
#    'cute': True,
#    'though': True,
#    'hoping': True,
#    'pawn': True,
#    'gil': True},
#   'Negative'),
#  ({'williammm': True,
#    'lol': True,
#    'know': True,
#    'always': True,
#    'think': True,
#    'go': True,
#    'vagina': True,
#    'monoglues': True,
#    'see': True,
#    'chocolate': True},
#   'Positive'),
#  ({'hmm': True,
#    'maybe': True,
#    'watch': True,
#    'movie': True,
#    'would': True,
#    'b': True,
#    'fun': True,
#    'guess': True,
#    'popcorn': True,
#    'kool': True,
#    'aid': True,
#    'find': True,
#    'new': True,
#    'snack': True},
#   'Negative'),
#  ({'showerguys': True,
#    'yay': True,
#    'go': True,
#    'wrong': True,
#    'g': True,
#    'n': True},
#   'Positive'),
#  ({'misshaleymae': True, 'know': True, 'baby': True, 'x': True}, 'Positive'),
#  ({'uber': True,
#    'cool': True,
#    'lunch': True,
#    'thanks': True,
#    'si': True,
#    'pic': True,
#    'posted': True,
#    'soon': True},
#   'Positive'),
#  ({'imreallydope': True, 'phone': True, 'working': True}, 'Negative'),
#  ({'cuteredshoes': True,
#    'dirty': True,
#    'girl': True,
#    'spambots': True,
#    'bug': True},
#   'Negative'),
#  ({'anthmuz': True, 'got': True, 'maccas': True}, 'Positive'),
#  ({'fuck': True,
#    'im': True,
#    'getting': True,
#    'need': True,
#    'human': True,
#    'physical': True,
#    'contact': True},
#   'Negative'),
#  ({'sueannesjewelry': True,
#    'yeah': True,
#    'martini': True,
#    'last': True,
#    'night': True,
#    'hopefully': True,
#    'downward': True,
#    'dog': True,
#    'turn': True,
#    'something': True,
#    'else': True},
#   'Positive'),
#  ({'danielmysterio': True, 'thanks': True, 'followfriday': True}, 'Positive'),
#  ({'mannnn': True,
#    'gern': True,
#    'man': True,
#    'lol': True,
#    'cnt': True,
#    'take': True,
#    'ganged': True},
#   'Negative'),
#  ({'finished': True, 'pepsi': True}, 'Negative'),
#  ({'taylor': True,
#    'swift': True,
#    'http': True,
#    'blip': True,
#    'fm': True,
#    'e': True,
#    'g': True,
#    'like': True,
#    'song': True},
#   'Positive'),
#  ({'shinybiscuit': True,
#    'wait': True,
#    'katrinonus': True,
#    'follow': True,
#    'cool': True},
#   'Positive'),
#  ({'jasonlarson': True,
#    'maybe': True,
#    'busy': True,
#    'filming': True,
#    'new': True,
#    'commercial': True,
#    'lol': True,
#    'well': True,
#    'lucky': True,
#    'papa': True,
#    'near': True},
#   'Negative'),
#  ({'sauna': True,
#    'alex': True,
#    'brandon': True,
#    'cait': True,
#    'probably': True,
#    'get': True,
#    'std': True,
#    'check': True},
#   'Positive'),
#  ({'matress': True,
#    'yelled': True,
#    'get': True,
#    'disgusting': True,
#    'filth': True},
#   'Negative'),
#  ({'sm': True, 'bad': True, 'either': True}, 'Positive'),
#  ({'heizeltm': True}, 'Positive'),
#  ({'e': True,
#    'book': True,
#    'dont': True,
#    'try': True,
#    'open': True,
#    'read': True,
#    'might': True,
#    'virus': True},
#   'Positive'),
#  ({'kitcat': True,
#    'good': True,
#    'morning': True,
#    'start': True,
#    'dish': True,
#    'blah': True},
#   'Negative'),
#  ({'dougiemcfly': True,
#    'haha': True,
#    'dude': True,
#    'b': True,
#    'date': True,
#    'p': True,
#    'wish': True,
#    'u': True,
#    'ur': True,
#    'day': True,
#    'oth': True,
#    'november': True,
#    'also': True,
#    'turn': True,
#    'reply': True,
#    'please': True},
#   'Positive'),
#  ({'wethetravis': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'eibi': True,
#    'alway': True,
#    'arigato': True,
#    'stuff': True,
#    'entertain': True},
#   'Positive'),
#  ({'stephd': True,
#    'charge': True,
#    'battery': True,
#    'overnight': True,
#    'might': True,
#    'find': True,
#    'place': True,
#    'sheree': True},
#   'Positive'),
#  ({'bigbakedbean': True,
#    'ooh': True,
#    'thanks': True,
#    'knew': True,
#    'one': True,
#    'exist': True},
#   'Positive'),
#  ({'going': True,
#    'see': True,
#    'lyndsey': True,
#    'lauren': True,
#    'last': True,
#    'time': True,
#    'ever': True},
#   'Negative'),
#  ({'coffee': True,
#    'looking': True,
#    'pain': True,
#    'apple': True,
#    'heart': True,
#    'soul': True,
#    'dying': True,
#    'iphone': True,
#    'day': True,
#    'numbered': True},
#   'Negative'),
#  ({'myrandalove': True,
#    'idk': True,
#    'sick': True,
#    'hope': True,
#    'concert': True,
#    'coming': True,
#    'throat': True,
#    'hurt': True},
#   'Negative'),
#  ({'liinnndzzooo': True,
#    'haha': True,
#    'love': True,
#    'tooo': True,
#    'would': True,
#    'never': True,
#    'talk': True,
#    'youuu': True,
#    'loll': True},
#   'Positive'),
#  ({'one': True,
#    'admiral': True,
#    'gwcville': True,
#    'love': True,
#    'fourm': True},
#   'Positive'),
#  ({'ughhh': True,
#    'get': True,
#    'help': True,
#    'move': True,
#    'aunt': True,
#    'today': True,
#    'much': True,
#    'fun': True},
#   'Negative'),
#  ({'legendarylagear': True,
#    'need': True,
#    'like': True,
#    'month': True,
#    'vacation': True,
#    'life': True},
#   'Negative'),
#  ({'omggggggggggg': True,
#    'video': True,
#    'young': True,
#    'lady': True,
#    'neda': True,
#    'shot': True,
#    'heart': True,
#    'sniper': True},
#   'Negative'),
#  ({'waitingtohappen': True, 'aha': True, 'well': True, 'good': True},
#   'Positive'),
#  ({'little': True,
#    'sister': True,
#    'told': True,
#    'double': True,
#    'chin': True,
#    'aww': True},
#   'Negative'),
#  ({'misty': True,
#    'glad': True,
#    'getting': True,
#    'peace': True,
#    'later': True,
#    'though': True,
#    'hey': True,
#    'keyboard': True,
#    'fab': True,
#    'battery': True,
#    'standby': True,
#    'good': True,
#    'night': True,
#    'xxxx': True},
#   'Positive'),
#  ({'verma': True,
#    'awesome': True,
#    'talk': True,
#    'find': True,
#    'true': True,
#    'watching': True,
#    'ruby': True,
#    'community': True,
#    'closely': True},
#   'Positive'),
#  ({'boring': True, 'day': True}, 'Negative'),
#  ({'lunch': True, 'break': True}, 'Positive'),
#  ({'watchin': True,
#    'suite': True,
#    'life': True,
#    'deck': True,
#    'hanging': True,
#    'vanessa': True,
#    'today': True,
#    'fuunn': True},
#   'Positive'),
#  ({'omg': True, 'raining': True}, 'Negative'),
#  ({'corvuse': True,
#    'badly': True,
#    'seems': True,
#    'like': True,
#    'bad': True,
#    'idea': True,
#    'give': True,
#    'another': True,
#    'shot': True,
#    'today': True},
#   'Positive'),
#  ({'love': True, 'talking': True, 'even': True, 'simple': True, 'word': True},
#   'Positive'),
#  ({'xpb': True,
#    'okay': True,
#    'long': True,
#    'know': True,
#    'enjoy': True,
#    'music': True,
#    'x': True},
#   'Negative'),
#  ({'shelvzthebatman': True,
#    'lol': True,
#    'newer': True,
#    'one': True,
#    'got': True,
#    'woman': True,
#    'singing': True,
#    'quite': True,
#    'dancy': True,
#    'think': True,
#    'forget': True,
#    'short': True,
#    'memory': True,
#    'span': True},
#   'Negative'),
#  ({'want': True,
#    'macbook': True,
#    'window': True,
#    'suck': True,
#    'creating': True,
#    'beatzz': True},
#   'Negative'),
#  ({'burre': True,
#    'maydbs': True,
#    'nevermind': True,
#    'euval': True,
#    'piratpartiet': True,
#    'maybe': True,
#    'ask': True,
#    'peterrosdahl': True,
#    'start': True,
#    'channel': True,
#    'svpt': True,
#    'nu': True},
#   'Positive'),
#  ({'littlefletcher': True,
#    'dunno': True,
#    'fletcher': True,
#    'day': True,
#    'either': True,
#    'lol': True,
#    'wanna': True,
#    'know': True,
#    'cause': True,
#    'love': True,
#    'guy': True,
#    'rock': True,
#    'xxxx': True},
#   'Positive'),
#  ({'duciaestherine': True,
#    'hihi': True,
#    'okay': True,
#    'soalnya': True,
#    'aku': True,
#    'takut': True,
#    'dia': True,
#    'tunggu': True,
#    'thank': True,
#    'much': True,
#    'princess': True,
#    'duce': True,
#    'cantik': True},
#   'Positive'),
#  ({'cherokeedassxxx': True,
#    'hey': True,
#    'cherokee': True,
#    'dis': True,
#    'cottoncandy': True,
#    'u': True,
#    'miss': True,
#    'ya': True,
#    'mwahz': True},
#   'Positive'),
#  ({'ok': True,
#    'asked': True,
#    'getting': True,
#    'highway': True,
#    'one': True,
#    'american': True,
#    'strat': True,
#    'today': True,
#    'tele': True,
#    'asking': True,
#    'friend': True,
#    'sorry': True,
#    'iphone': True,
#    'g': True},
#   'Negative'),
#  ({'laying': True,
#    'outside': True,
#    'big': True,
#    'warm': True,
#    'blanket': True,
#    'nearly': True,
#    'fun': True,
#    'alone': True},
#   'Negative'),
#  ({'lazy': True, 'sunday': True}, 'Positive'),
#  ({'writing': True,
#    'chap': True,
#    'freakinspecial': True,
#    'finished': True,
#    'awesome': True,
#    'word': True},
#   'Positive'),
#  ({'shazzib': True}, 'Negative'),
#  ({'boom': True, 'pow': True}, 'Positive'),
#  ({'uliwitness': True,
#    'yeah': True,
#    'expect': True,
#    'funny': True,
#    'explained': True,
#    'stand': True,
#    'feeling': True,
#    'missing': True,
#    'something': True},
#   'Positive'),
#  ({'benjamineck': True, 'oooo': True, 'exciting': True}, 'Positive'),
#  ({'school': True,
#    'last': True,
#    'week': True,
#    'sam': True,
#    'taylor': True,
#    'dress': True,
#    'fitting': True,
#    'afterwardsss': True},
#   'Negative'),
#  ({'say': True,
#    'month': True,
#    'since': True,
#    'david': True,
#    'left': True,
#    'philippine': True,
#    'hahaha': True,
#    'davidarchie': True},
#   'Negative'),
#  ({'omg': True,
#    'watching': True,
#    'tv': True,
#    'angel': True,
#    'lo': True,
#    'tel': True,
#    'started': True,
#    'playing': True,
#    'bg': True,
#    'show': True,
#    'biggest': True,
#    'throwback': True,
#    'ever': True,
#    'cant': True,
#    'find': True,
#    'anywhere': True,
#    'dl': True},
#   'Negative'),
#  ({'tonia': True,
#    'enjoy': True,
#    'giving': True,
#    'compliment': True,
#    'make': True,
#    'easy': True},
#   'Positive'),
#  ({'door': True,
#    'grocery': True,
#    'store': True,
#    'yeah': True,
#    'time': True,
#    'buy': True,
#    'healthy': True,
#    'eats': True},
#   'Positive'),
#  ({'mtv': True,
#    'movie': True,
#    'award': True,
#    'please': True,
#    'still': True,
#    'know': True,
#    'watch': True},
#   'Negative'),
#  ({'got': True, 'flu': True, 'sistem': True}, 'Negative'),
#  ({'plaintruthiness': True,
#    'disaster': True,
#    'think': True,
#    'end': True,
#    'world': True},
#   'Negative'),
#  ({'mellowmelia': True,
#    'ya': True,
#    'dog': True,
#    'u': True,
#    'know': True,
#    'type': True,
#    'fast': True,
#    'im': True,
#    'speed': True,
#    'demon': True},
#   'Positive'),
#  ({'lovejoann': True,
#    'aww': True,
#    'thats': True,
#    'sweet': True,
#    'boyfriend': True,
#    'lonely': True},
#   'Negative'),
#  ({'ok': True,
#    'pic': True,
#    'set': True,
#    'papa': True,
#    'birthday': True,
#    'cake': True,
#    'sure': True,
#    'made': True,
#    'tho': True,
#    'si': True,
#    'granny': True,
#    'dunno': True,
#    'never': True,
#    'got': True},
#   'Negative'),
#  ({'watching': True, 'day': True, 'life': True}, 'Positive'),
#  ({'heidimontag': True,
#    'omg': True,
#    'wait': True,
#    'see': True,
#    'give': True,
#    'secrct': True,
#    'shout': True,
#    'wave': True,
#    'know': True,
#    'rotfl': True},
#   'Positive'),
#  ({'pissed': True, 'broke': True, 'favorite': True, 'jean': True}, 'Negative'),
#  ({'sashakane': True, 'kind': True, 'awesome': True}, 'Positive'),
#  ({'aslanwrp': True,
#    'far': True,
#    'believe': True,
#    'tx': True,
#    'year': True,
#    'dallas': True,
#    'twice': True,
#    'much': True,
#    'traffic': True},
#   'Positive'),
#  ({'lovisatalk': True, 'thanks': True, 'anyway': True}, 'Positive'),
#  ({'jeremy': True,
#    'lamont': True,
#    'yr': True,
#    'young': True,
#    'looking': True,
#    'dude': True},
#   'Positive'),
#  ({'friday': True,
#    'look': True,
#    'like': True,
#    'finally': True,
#    'going': True,
#    'rain': True,
#    'vancouver': True,
#    'good': True,
#    'bye': True,
#    'sun': True},
#   'Negative'),
#  ({'emmyrossum': True,
#    'prom': True,
#    'supposed': True,
#    'yesterday': True,
#    'canceled': True,
#    'due': True,
#    'snow': True},
#   'Negative'),
#  ({'officialas': True,
#    'without': True,
#    'asa': True,
#    'sorry': True,
#    'know': True,
#    'already': True},
#   'Negative'),
#  ({'however': True,
#    'willing': True,
#    'learn': True,
#    'visiting': True,
#    'place': True,
#    'ppl': True,
#    'http': True,
#    'plurk': True,
#    'com': True,
#    'p': True,
#    'touth': True},
#   'Positive'),
#  ({'die': True, 'poor': True, 'man': True}, 'Negative'),
#  ({'great': True, 'day': True}, 'Positive'),
#  ({'going': True, 'get': True, 'beautiful': True, 'car': True, 'washed': True},
#   'Positive'),
#  ({'sitting': True,
#    'reading': True,
#    'twitter': True,
#    'instead': True,
#    'going': True,
#    'back': True,
#    'uni': True},
#   'Positive'),
#  ({'aspenspin': True, 'nothing': True, 'got': True}, 'Positive'),
#  ({'mid': True, 'coastal': True, 'weekend': True, 'yes': True}, 'Positive'),
#  ({'asked': True,
#    'sing': True,
#    'yet': True,
#    'aha': True,
#    'coffee': True,
#    'mornin': True,
#    'time': True,
#    'psychology': True,
#    'past': True,
#    'question': True,
#    'amp': True,
#    'revision': True,
#    'suck': True},
#   'Positive'),
#  ({'terrible': True, 'cartoon': True, 'supposed': True, 'mexican': True},
#   'Negative'),
#  ({'mileycyrus': True,
#    'http': True,
#    'twitpic': True,
#    'com': True,
#    'pf': True,
#    'v': True,
#    'u': True,
#    'look': True,
#    'great': True},
#   'Positive'),
#  ({'watching': True, 'tv': True, 'whole': True, 'fam': True}, 'Positive'),
#  ({'b': True, 'soon': True, 'claim': True, 'coffee': True}, 'Positive'),
#  ({'keep': True,
#    'reading': True,
#    'contract': True,
#    'cataract': True,
#    'someone': True,
#    'bring': True,
#    'panera': True},
#   'Negative'),
#  ({'taking': True,
#    'little': True,
#    'one': True,
#    'airport': True,
#    'visit': True,
#    'dad': True,
#    'vega': True,
#    'couple': True,
#    'hour': True,
#    'dreading': True},
#   'Negative'),
#  ({'rgoodchild': True,
#    'say': True,
#    'hamilton': True,
#    'born': True,
#    'bred': True,
#    'take': True,
#    'back': True,
#    'prior': True,
#    'comment': True},
#   'Negative'),
#  ({'kip': True, 'oh': True, 'remind': True, 'choice': True, 'thing': True},
#   'Positive'),
#  ({'seenandsaid': True, 'hear': True, 'thunder': True}, 'Negative'),
#  ({'woah': True,
#    'incredible': True,
#    'time': True,
#    'king': True,
#    'island': True,
#    'sadder': True,
#    'note': True,
#    'jon': True,
#    'kate': True,
#    'getting': True,
#    'divorced': True,
#    'oh': True,
#    'crap': True},
#   'Negative'),
#  ({'start': True,
#    'semi': True,
#    'moderating': True,
#    'blog': True,
#    'comment': True,
#    'want': True,
#    'really': True,
#    'choice': True},
#   'Negative'),
#  ({'watched': True,
#    'cadillac': True,
#    'record': True,
#    'inspiring': True,
#    'kind': True,
#    'sad': True,
#    'http': True,
#    'blip': True,
#    'fm': True,
#    'gyhj': True},
#   'Positive'),
#  ({'firioo': True,
#    'went': True,
#    'aunt': True,
#    'place': True,
#    'fun': True,
#    'blogging': True,
#    'plurking': True,
#    'tweeting': True},
#   'Positive'),
#  ({'magpiesparkles': True,
#    'happy': True,
#    'birthday': True,
#    'hope': True,
#    'ur': True,
#    'treated': True,
#    'like': True,
#    'princess': True,
#    'today': True,
#    'xx': True},
#   'Positive'),
#  ({'donniewahlberg': True,
#    'ok': True,
#    'feel': True,
#    'like': True,
#    'u': True,
#    'r': True,
#    'breaking': True,
#    'moment': True,
#    'waiting': True,
#    'break': True,
#    'song': True,
#    'quot': True,
#    'officially': True},
#   'Negative'),
#  ({'borrrrd': True, 'work': True, 'x': True}, 'Negative'),
#  ({'krystinascott': True,
#    'could': True,
#    'sleep': True,
#    'hour': True,
#    'im': True,
#    'still': True,
#    'feeling': True,
#    'sleepy': True,
#    'crashing': True,
#    'head': True,
#    'desk': True,
#    'think': True,
#    'really': True,
#    'need': True,
#    'vacation': True,
#    'hows': True,
#    'u': True},
#   'Negative'),
#  ({'good': True, 'playing': True, 'poker': True}, 'Negative'),
#  ({'folllow': True,
#    'follow': True,
#    'back': True,
#    'goooood': True,
#    'niiight': True},
#   'Positive'),
#  ({'uploading': True,
#    'ringtones': True,
#    'matt': True,
#    'thenn': True,
#    'going': True},
#   'Negative'),
#  ({'booby': True,
#    'huuurt': True,
#    'man': True,
#    'season': True,
#    'hurtn': True,
#    'bdays': True,
#    'grad': True,
#    'wheew': True,
#    'expensivee': True},
#   'Negative'),
#  ({'g': True,
#    'morning': True,
#    'twitter': True,
#    'world': True,
#    'relaxing': True,
#    'family': True,
#    'sunday': True,
#    'methinks': True},
#   'Positive'),
#  ({'far': True, 'early': True}, 'Negative'),
#  ({'brax': True, 'wish': True, 'busy': True, 'sunday': True}, 'Negative'),
#  ({'listening': True,
#    'leaked': True,
#    'passion': True,
#    'pit': True,
#    'album': True,
#    'still': True,
#    'going': True,
#    'buy': True,
#    'though': True,
#    'come': True,
#    'listen': True},
#   'Positive'),
#  ({'one': True, 'office': True, 'min': True, 'go': True}, 'Negative'),
#  ({'wanna': True, 'work': True, 'day': True, 'tired': True, 'coffee': True},
#   'Negative'),
#  ({'found': True,
#    'something': True,
#    'interesting': True,
#    'yesterday': True,
#    'purple': True,
#    'corn': True,
#    'really': True,
#    'grows': True,
#    'peru': True,
#    'made': True,
#    'juice': True},
#   'Positive'),
#  ({'idkmybffleah': True,
#    'haha': True,
#    'yea': True,
#    'like': True,
#    'disney': True,
#    'vhs': True,
#    'amp': True,
#    'old': True,
#    'home': True,
#    'movie': True,
#    'better': True,
#    'record': True,
#    'dvd': True,
#    'gone': True,
#    'soon': True},
#   'Negative'),
#  ({'miss': True,
#    'boyfriend': True,
#    'brutus': True,
#    'crazy': True,
#    'sidekick': True,
#    'dudley': True},
#   'Negative'),
#  ({'idril': True,
#    'ilae': True,
#    'sigh': True,
#    'easy': True,
#    'always': True,
#    'stressing': True,
#    'much': True,
#    'silly': True,
#    'trying': True,
#    'perfect': True,
#    'xx': True},
#   'Positive'),
#  ({'work': True}, 'Positive'),
#  ({'missjessieleex': True,
#    'working': True,
#    'today': True,
#    'really': True,
#    'well': True,
#    'essay': True,
#    'love': True},
#   'Positive'),
#  ({'omg': True,
#    'miss': True,
#    'meg': True,
#    'much': True,
#    'twinkle': True,
#    'darn': True,
#    'come': True,
#    'home': True,
#    'china': True,
#    'nowww': True},
#   'Negative'),
#  ({'first': True,
#    'impression': True,
#    'genius': True,
#    'bar': True,
#    'slow': True,
#    'bit': True,
#    'disappointed': True,
#    'still': True,
#    'waiting': True,
#    'idea': True,
#    'seen': True},
#   'Negative'),
#  ({'feel': True,
#    'really': True,
#    'bad': True,
#    'going': True,
#    'school': True,
#    'tomorrow': True,
#    'im': True,
#    'sorry': True,
#    'alys': True},
#   'Negative'),
#  ({'happy': True, 'birthday': True, 'need': True, 'buy': True, 'cake': True},
#   'Positive'),
#  ({'damn': True, 'scare': True, 'could': True, 'go': True, 'andys': True},
#   'Positive'),
#  ({'kimjarrett': True,
#    'thats': True,
#    'allll': True,
#    'sleep': True,
#    'tho': True,
#    'energy': True,
#    'anything': True,
#    'uugh': True,
#    'hope': True,
#    'get': True,
#    'back': True,
#    'normal': True,
#    'lol': True},
#   'Negative'),
#  ({'kristengilmore': True,
#    'gonna': True,
#    'lie': True,
#    'awesome': True,
#    'get': True,
#    'way': True,
#    'awake': True},
#   'Negative'),
#  ({'malcolmmillion': True,
#    'aww': True,
#    'thanks': True,
#    'yeah': True,
#    'please': True},
#   'Positive'),
#  ({'celebrated': True,
#    'st': True,
#    'father': True,
#    'day': True,
#    'airport': True,
#    'becki': True,
#    'awsome': True,
#    'job': True,
#    'making': True,
#    'special': True,
#    'regardless': True,
#    'lucky': True,
#    'man': True,
#    'amp': True,
#    'proud': True,
#    'dad': True},
#   'Negative'),
#  ({'long': True,
#    'day': True,
#    'amp': True,
#    'night': True,
#    'ahead': True,
#    'arrive': True,
#    'brusels': True,
#    'nyc': True,
#    'h': True,
#    'loiu': True,
#    'airport': True,
#    'closed': True,
#    'nice': True,
#    'trip': True,
#    'starting': True},
#   'Negative'),
#  ({'cleaning': True, 'room': True, 'listening': True, 'britney': True},
#   'Positive'),
#  ({'mr': True,
#    'mcd': True,
#    'ok': True,
#    'thats': True,
#    'much': True,
#    'better': True,
#    'got': True,
#    'earphone': True,
#    'spotify': True,
#    'still': True,
#    'ever': True},
#   'Positive'),
#  ({'hour': True, 'go': True, 'leaving': True, 'south': True}, 'Negative'),
#  ({'maynaseric': True,
#    'hehe': True,
#    'thanks': True,
#    'one': True,
#    'photo': True,
#    'take': True,
#    'reuse': True,
#    'later': True,
#    'life': True},
#   'Positive'),
#  ({'last': True,
#    'night': True,
#    'carnage': True,
#    'fun': True,
#    'beautiful': True,
#    'twisted': True,
#    'love': True,
#    'kenya': True,
#    'crew': True,
#    'boy': True,
#    'much': True},
#   'Positive'),
#  ({'trovus': True,
#    'tuesday': True,
#    'breakfast': True,
#    'currently': True,
#    'meet': True,
#    'greet': True,
#    'thing': True,
#    'http': True,
#    'www': True,
#    'co': True,
#    'uk': True},
#   'Positive'),
#  ({'pattidigh': True,
#    'ah': True,
#    'exuberance': True,
#    'resilience': True,
#    'young': True,
#    'leg': True},
#   'Positive'),
#  ({'bolanile': True, 'hey': True, 'u': True, 'city': True, 'dirty': True},
#   'Positive'),
#  ({'going': True,
#    'bed': True,
#    'hopefully': True,
#    'get': True,
#    'kicked': True,
#    'like': True,
#    'last': True,
#    'night': True},
#   'Positive'),
#  ({'good': True,
#    'weekend': True,
#    'manchester': True,
#    'searched': True,
#    'forever': True,
#    'baby': True,
#    'cake': True,
#    'found': True,
#    'rather': True,
#    'dissappointed': True,
#    'xxx': True},
#   'Negative'),
#  ({'feeling': True,
#    'horrid': True,
#    'nose': True,
#    'burning': True,
#    'eye': True,
#    'watering': True,
#    'body': True,
#    'sore': True,
#    'already': True,
#    'bed': True},
#   'Negative'),
#  ({'benjamin': True,
#    'button': True,
#    'made': True,
#    'cry': True,
#    'sad': True,
#    'oh': True,
#    'way': True,
#    'love': True,
#    'daisy': True},
#   'Negative'),
#  ({'mommy': True, 'day': True, 'spending': True, 'momma': True}, 'Positive'),
#  ({'chill': True, 'one': True, 'freaking': True}, 'Positive'),
#  ({'school': True,
#    'culinary': True,
#    'hair': True,
#    'comfirmation': True,
#    'dinner': True},
#   'Positive'),
#  ({'brassangel': True,
#    'gyul': True,
#    'aint': True,
#    'find': True,
#    'manager': True},
#   'Negative'),
#  ({'ralphp': True, 'eagerly': True, 'anticipating': True, 'twitpics': True},
#   'Positive'),
#  ({'enjoying': True, 'sun': True, 'day': True}, 'Positive'),
#  ({'quot': True,
#    'seeing': True,
#    'everyday': True,
#    'made': True,
#    'shit': True,
#    'happened': True,
#    'worthwhile': True,
#    'aweh': True,
#    'tyty': True,
#    'miss': True,
#    'muchly': True,
#    'day': True},
#   'Negative'),
#  ({'omg': True,
#    'way': True,
#    'much': True,
#    'stuff': True,
#    'dont': True,
#    'think': True,
#    'enough': True,
#    'room': True,
#    'new': True,
#    'place': True},
#   'Negative'),
#  ({'degrassinsider': True,
#    'newhere': True,
#    'full': True,
#    'episode': True,
#    'season': True,
#    'amp': True,
#    'sum': True,
#    'n': True,
#    'website': True,
#    'one': True,
#    'looking': True},
#   'Negative'),
#  ({'thought': True,
#    'bb': True,
#    'getting': True,
#    'response': True,
#    'text': True,
#    'turn': True,
#    'network': True,
#    'fine': True,
#    'ppl': True,
#    'texting': True,
#    'back': True},
#   'Negative'),
#  ({'tysninnie': True,
#    'sorry': True,
#    'feeling': True,
#    'bad': True,
#    'lot': True,
#    'healing': True,
#    'thought': True,
#    'going': True,
#    'way': True},
#   'Negative'),
#  ({'chrisdjmoyles': True,
#    'believe': True,
#    'rumour': True,
#    'anyway': True,
#    'miss': True,
#    'radio': True,
#    'watching': True,
#    'quiz': True,
#    'tonight': True},
#   'Positive'),
#  ({'fml': True,
#    'laptop': True,
#    'charge': True,
#    'cord': True,
#    'thing': True,
#    'doesnt': True,
#    'work': True,
#    'anymore': True,
#    'died': True},
#   'Negative'),
#  ({'listening': True,
#    'kix': True,
#    'accc': True,
#    'broadcast': True,
#    'special': True,
#    'co': True,
#    'host': True,
#    'mr': True,
#    'dierks': True,
#    'bentley': True},
#   'Positive'),
#  ({'never': True,
#    'travelling': True,
#    'aeroplane': True,
#    'ever': True,
#    'scary': True,
#    'dream': True,
#    'last': True,
#    'night': True,
#    'going': True,
#    'barbados': True},
#   'Negative'),
#  ({'johannschwella': True,
#    'welcome': True,
#    'oh': True,
#    'jadedsantos': True,
#    'noting': True,
#    'whatsoever': True,
#    'nothing': True},
#   'Positive'),
#  ({'beautiful': True,
#    'day': True,
#    'time': True,
#    'say': True,
#    'goodnight': True},
#   'Positive'),
#  ({'nope': True,
#    'stomach': True,
#    'cramping': True,
#    'back': True,
#    'mid': True,
#    'labor': True,
#    'hard': True,
#    'al': True,
#    'lost': True},
#   'Negative'),
#  ({'watched': True,
#    'good': True,
#    'glasgow': True,
#    'folk': True,
#    'debating': True,
#    'bnp': True,
#    'rep': True,
#    'fun': True,
#    'reassuring': True,
#    'quarter': True,
#    'given': True,
#    'deserved': True},
#   'Positive'),
#  ({'b': True,
#    'lz': True,
#    'bub': True,
#    'lol': True,
#    'miss': True,
#    'movie': True,
#    'around': True,
#    'somewhere': True,
#    'gotta': True,
#    'watch': True},
#   'Positive'),
#  ({'kenosha': True,
#    'aikido': True,
#    'lol': True,
#    'true': True,
#    'thank': True,
#    'got': True,
#    'tweet': True,
#    'please': True,
#    'ignore': True,
#    'quot': True,
#    'contact': True,
#    'u': True,
#    'submission': True,
#    'issue': True,
#    'lt': True,
#    'rei': True,
#    'gt': True},
# ...
#    'boom': True,
#    'pow': True,
#    'lol': True,
#    'lt': True},
#   'Negative'),
#  ({'flowerhope': True, 'noahcyrus': True, 'twitter': True}, 'Negative'),
#  ({'teenormous': True,
#    'child': True,
#    'black': True,
#    'white': True,
#    'tv': True,
#    'gang': True,
#    'sunday': True,
#    'morning': True,
#    'tarzan': True,
#    'godzilla': True,
#    'rerun': True,
#    'part': True,
#    'life': True},
#   'Positive'),
#  ({'people': True,
#    'follow': True,
#    'whole': True,
#    'twitter': True,
#    'world': True},
#   'Negative'),
#  ({'ctwink': True,
#    'keep': True,
#    'forgetting': True,
#    'need': True,
#    'tweet': True},
#   'Positive'),
#  ({'realised': True,
#    'long': True,
#    'since': True,
#    'last': True,
#    'tweeting': True,
#    'know': True,
#    'say': True,
#    'x': True},
#   'Positive'),
#  ({'popsquire': True,
#    'wish': True,
#    'could': True,
#    'la': True,
#    'sometimes': True,
#    'meet': True,
#    'guy': True,
#    'fabulous': True},
#   'Positive'),
#  ({'http': True,
#    'twitpic': True,
#    'com': True,
#    'tkot': True,
#    'besties': True,
#    'ddlovato': True},
#   'Negative'),
#  ({'found': True,
#    'last': True,
#    'titanic': True,
#    'survivor': True,
#    'died': True,
#    'yesterday': True,
#    'goggled': True,
#    'long': True,
#    'ago': True,
#    'awfully': True,
#    'sad': True},
#   'Negative'),
#  ({'bogvampwhoppit': True, 'grey': True, 'cheshire': True}, 'Negative'),
#  ({'way': True,
#    'home': True,
#    'suffered': True,
#    'one': True,
#    'injury': True,
#    'helping': True,
#    'pack': True,
#    'marquee': True},
#   'Negative'),
#  ({'meheartrihanna': True,
#    'lol': True,
#    'yuu': True,
#    'notice': True,
#    'get': True,
#    'postive': True,
#    'comment': True,
#    'yay': True,
#    'claudia': True,
#    'hmm': True,
#    'changed': True,
#    'username': True,
#    'lt': True},
#   'Positive'),
#  ({'stressing': True, 'wondering': True, 'right': True, 'decision': True},
#   'Negative'),
#  ({'mileycyrus': True,
#    'aj': True,
#    'rafael': True,
#    'awesome': True,
#    'musician': True,
#    'famous': True,
#    'youtube': True,
#    'covered': True,
#    'song': True,
#    'climb': True,
#    'please': True,
#    'watch': True,
#    'good': True,
#    'http': True,
#    'bit': True,
#    'ly': True,
#    'si': True},
#   'Positive'),
#  ({'omg': True,
#    'studyed': True,
#    'hour': True,
#    'happened': True,
#    'one': True,
#    'tree': True,
#    'hill': True,
#    'background': True},
#   'Positive'),
#  ({'idk': True, 'rachel': True, 'another': True, 'one': True, 'tried': True},
#   'Negative'),
#  ({'garymac': True,
#    'yes': True,
#    'kind': True,
#    'bit': True,
#    'feart': True,
#    'case': True,
#    'driving': True,
#    'scare': True,
#    'get': True,
#    'home': True,
#    'till': True,
#    'eleven': True,
#    'tomorrow': True,
#    'night': True},
#   'Negative'),
#  ({'capnmarrrrk': True, 'ticket': True, 'sale': True, 'yes': True},
#   'Positive'),
#  ({'rubyletters': True, 'zactly': True, 'morning': True}, 'Positive'),
#  ({'concert': True, 'would': True, 'make': True, 'weekend': True}, 'Negative'),
#  ({'sebby': True,
#    'peek': True,
#    'oh': True,
#    'yes': True,
#    'bloody': True,
#    'well': True},
#   'Positive'),
#  ({'big': True,
#    'help': True,
#    'tehgrumpydude': True,
#    'http': True,
#    'www': True,
#    'xnadevelopment': True,
#    'com': True,
#    'sporting': True,
#    'snazzy': True,
#    'new': True,
#    'look': True,
#    'beautiful': True,
#    'love': True},
#   'Positive'),
#  ({'found': True,
#    'negative': True,
#    'lost': True,
#    'wait': True,
#    'photography': True,
#    'exam': True},
#   'Positive'),
#  ({'lizandkevin': True,
#    'hello': True,
#    'toronto': True,
#    'maybe': True,
#    'help': True},
#   'Positive'),
#  ({'performing': True,
#    'today': True,
#    'town': True,
#    'looking': True,
#    'forward': True},
#   'Positive'),
#  ({'thedonraimo': True,
#    'haha': True,
#    'omg': True,
#    'really': True,
#    'crack': True,
#    'papa': True,
#    'know': True,
#    'always': True,
#    'make': True,
#    'best': True,
#    'situation': True},
#   'Positive'),
#  ({'xcaptainx': True, 'ashamed': True}, 'Negative'),
#  ({'heloloser': True,
#    'thanks': True,
#    'clair': True,
#    'watched': True,
#    'yet': True},
#   'Negative'),
#  ({'also': True, 'leaving': True, 'see': True, 'train': True}, 'Positive'),
#  ({'lindseylu': True,
#    'two': True,
#    'year': True,
#    'ago': True,
#    'jlist': True,
#    'everyone': True,
#    'double': True,
#    'take': True,
#    'said': True,
#    'quot': True,
#    'hand': True,
#    'massager': True},
#   'Negative'),
#  ({'ayee': True,
#    'freakin': True,
#    'lip': True,
#    'ring': True,
#    'small': True,
#    'look': True,
#    'ugly': True},
#   'Negative'),
#  ({'find': True, 'job': True}, 'Negative'),
#  ({'well': True,
#    'went': True,
#    'good': True,
#    'day': True,
#    'something': True,
#    'always': True,
#    'come': True,
#    'along': True,
#    'fuck': True,
#    'thing': True},
#   'Negative'),
#  ({'studying': True, 'exam': True}, 'Negative'),
#  ({'way': True}, 'Positive'),
#  ({'smoothdadude': True,
#    'brothaaaa': True,
#    'soo': True,
#    'much': True,
#    'without': True,
#    'ya': True,
#    'weekend': True},
#   'Negative'),
#  ({'kirstyannx': True,
#    'think': True,
#    'might': True,
#    'watch': True,
#    'tomorow': True,
#    'night': True,
#    'lol': True},
#   'Positive'),
#  ({'also': True,
#    'made': True,
#    'awkward': True,
#    'eye': True,
#    'contact': True,
#    'guy': True,
#    'car': True,
#    'next': True,
#    'mine': True,
#    'pretty': True,
#    'hot': True,
#    'staring': True},
#   'Negative'),
#  ({'miss': True, 'family': True}, 'Negative'),
#  ({'mspennypink': True,
#    'oh': True,
#    'forgot': True,
#    'party': True,
#    'quite': True,
#    'possibly': True,
#    'worst': True,
#    'friend': True,
#    'sorry': True,
#    'fun': True,
#    'though': True},
#   'Negative'),
#  ({'found': True,
#    'pop': True,
#    'star': True,
#    'airport': True,
#    'couple': True,
#    'streethearts': True,
#    'beautiful': True,
#    'sunny': True,
#    'bergen': True,
#    'today': True},
#   'Positive'),
#  ({'chatting': True,
#    'anouschka': True,
#    'came': True,
#    'back': True,
#    'outside': True,
#    'hot': True,
#    'love': True,
#    'sooo': True},
#   'Positive'),
#  ({'lazygenius': True, 'complain': True, 'sun': True, 'happy': True},
#   'Positive'),
#  ({'doesnt': True,
#    'feel': True,
#    'gud': True,
#    'may': True,
#    'work': True,
#    'day': True},
#   'Negative'),
#  ({'wishing': True, 'correy': True}, 'Negative'),
#  ({'donniewahlberg': True, 'need': True, 'twugged': True, 'today': True},
#   'Negative'),
#  ({'nice': True,
#    'time': True,
#    'katie': True,
#    'steve': True,
#    'last': True,
#    'night': True,
#    'bubble': True,
#    'gum': True,
#    'shoot': True,
#    'fab': True,
#    'roo': True},
#   'Positive'),
#  ({'okay': True,
#    'trying': True,
#    'happy': True,
#    'deal': True,
#    'problem': True,
#    'friend': True,
#    'also': True,
#    'hard': True},
#   'Negative'),
#  ({'ok': True,
#    'think': True,
#    'figured': True,
#    'twitter': True,
#    'wait': True,
#    'u': True,
#    'cant': True,
#    'upload': True,
#    'pic': True,
#    'kind': True,
#    'suck': True},
#   'Negative'),
#  ({'darn': True,
#    'really': True,
#    'want': True,
#    'play': True,
#    'tennis': True,
#    'tooo': True,
#    'late': True},
#   'Negative'),
#  ({'im': True,
#    'somewhat': True,
#    'didsapointed': True,
#    'wih': True,
#    'joker': True,
#    'lego': True,
#    'batman': True,
#    'he': True,
#    'cool': True,
#    'enough': True},
#   'Negative'),
#  ({'want': True, 'leave': True, 'already': True, 'bored': True, 'tired': True},
#   'Negative'),
#  ({'delwilliams': True, 'goodnite': True}, 'Positive'),
#  ({'upset': True,
#    'forgot': True,
#    'log': True,
#    'facebook': True,
#    'n': True,
#    'jerk': True,
#    'posted': True,
#    'quot': True,
#    'love': True,
#    'getting': True,
#    'high': True,
#    'work': True,
#    'professional': True,
#    'acquaintance': True},
#   'Negative'),
#  ({'hi': True, 'mukund': True, 'nice': True, 'see': True, 'tweet': True},
#   'Positive'),
#  ({'pfft': True,
#    'sometimes': True,
#    'wonder': True,
#    'waske': True,
#    'still': True,
#    'want': True,
#    'sleep': True},
#   'Negative'),
#  ({'patpreezy': True,
#    'send': True,
#    'u': True,
#    'another': True,
#    'unanswered': True,
#    'im': True,
#    'ima': True,
#    'cry': True,
#    'yo': True},
#   'Negative'),
#  ({'deannatroupe': True,
#    'actually': True,
#    'since': True,
#    'retweeted': True,
#    'kern': True,
#    'one': True,
#    'follower': True,
#    'apparently': True,
#    'tweetlater': True},
#   'Negative'),
#  ({'wanna': True,
#    'sign': True,
#    'twitter': True,
#    'addictive': True,
#    'diva': True,
#    'beyonce': True,
#    'growing': True},
#   'Positive'),
#  ({'worst': True, 'headache': True, 'ever': True}, 'Negative'),
#  ({'listed': True,
#    'new': True,
#    'item': True,
#    'check': True,
#    'today': True,
#    'http': True,
#    'poshadornment': True,
#    'etsy': True,
#    'com': True},
#   'Positive'),
#  ({'watching': True, 'quot': True, 'eurovision': True, 'lol': True},
#   'Positive'),
#  ({'work': True,
#    'half': True,
#    'hour': True,
#    'till': True,
#    'holiday': True,
#    'yay': True},
#   'Positive'),
#  ({'waiting': True,
#    'daddy': True,
#    'ome': True,
#    'deorating': True,
#    'lovely': True,
#    'sunny': True,
#    'day': True,
#    'shopping': True,
#    'time': True,
#    'afternoon': True},
#   'Positive'),
#  ({'liking': True,
#    'seesmic': True,
#    'desktop': True,
#    'far': True,
#    'great': True,
#    'multiple': True,
#    'account': True},
#   'Positive'),
#  ({'eskimo': True,
#    'jumper': True,
#    'sooo': True,
#    'cold': True,
#    'miss': True,
#    'summer': True},
#   'Negative'),
#  ({'good': True,
#    'morning': True,
#    'wide': True,
#    'awake': True,
#    'hot': True,
#    'coffee': True,
#    'hand': True,
#    'clearing': True,
#    'dvr': True,
#    'watching': True,
#    'house': True,
#    'love': True,
#    'hugh': True,
#    'laurie': True,
#    'actor': True,
#    'tootle': True},
#   'Positive'),
#  ({'hotmomamy': True, 'lol': True, 'worry': True}, 'Positive'),
#  ({'depressed': True, 'ugh': True, 'help': True}, 'Negative'),
#  ({'boudga': True,
#    'lol': True,
#    'oh': True,
#    'know': True,
#    'rather': True,
#    'chemical': True,
#    'bug': True},
#   'Positive'),
#  ({'kerryisonfire': True,
#    'kerrrrrrrrry': True,
#    'wheres': True,
#    'thing': True,
#    'steal': True,
#    'youtube': True,
#    'video': True},
#   'Positive'),
#  ({'coloneltribune': True,
#    'mega': True,
#    'texas': True,
#    'wife': True,
#    'going': True,
#    'happy': True},
#   'Positive'),
#  ({'informed': True,
#    'via': True,
#    'dm': True,
#    'follower': True,
#    'tweet': True,
#    'scared': True,
#    'huh': True,
#    'super': True,
#    'sweet': True,
#    'nice': True,
#    'hmph': True},
#   'Negative'),
#  ({'maureenjohnson': True, 'must': True, 'leakyfloo': True}, 'Negative'),
#  ({'homework': True,
#    'handed': True,
#    'time': True,
#    'get': True,
#    'detention': True,
#    'woohoo': True,
#    'still': True,
#    'done': True,
#    'either': True,
#    'beer': True,
#    'festival': True,
#    'mo': True,
#    'like': True},
#   'Negative'),
#  ({'reannahere': True,
#    'dang': True,
#    'invited': True,
#    'andrew': True,
#    'hope': True,
#    'come': True},
#   'Negative'),
#  ({'wicked': True,
#    'http': True,
#    'tinyurl': True,
#    'com': True,
#    'c': True,
#    'qb': True},
#   'Positive'),
#  ({'tsuki': True, 'watched': True, 'yesterday': True, 'night': True},
#   'Positive'),
#  ({'toastery': True,
#    'probably': True,
#    'one': True,
#    'tim': True,
#    'july': True,
#    'work': True,
#    'may': True,
#    'amp': True,
#    'june': True},
#   'Negative'),
#  ({'racheal': True, 'thanks': True, 'wo': True}, 'Positive'),
#  ({'two': True,
#    'day': True,
#    'ago': True,
#    'eject': True,
#    'nice': True,
#    'performance': True,
#    'echo': True,
#    'amp': True,
#    'thebunnymen': True,
#    'jarvis': True,
#    'cocker': True,
#    'interesting': True,
#    'act': True,
#    'klaxon': True,
#    'royksopp': True,
#    'wannabe': True,
#    'fest': True},
#   'Negative'),
#  ({'work': True, 'call': True, 'see': True, 'later': True}, 'Positive'),
#  ({'computer': True, 'broken': True}, 'Negative'),
#  ({'wide': True, 'awake': True, 'still': True, 'bored': True}, 'Negative'),
#  ({'retweeting': True,
#    'cocoate': True,
#    'drupal': True,
#    'acquia': True,
#    'silver': True,
#    'partner': True,
#    'http': True,
#    'gd': True,
#    'w': True,
#    'c': True},
#   'Positive'),
#  ({'foodstories': True,
#    'sianysianysiany': True,
#    'must': True,
#    'twiglets': True,
#    'roast': True,
#    'pork': True,
#    'till': True,
#    'pay': True,
#    'day': True},
#   'Negative'),
#  ({'sharemefg': True,
#    'gaim': True,
#    'nonlinux': True,
#    'pidgin': True,
#    'im': True,
#    'irc': True,
#    'plugin': True,
#    'year': True,
#    'port': True,
#    'code': True,
#    'twitter': True,
#    'exciting': True,
#    'adium': True,
#    'bit': True,
#    'heavy': True},
#   'Positive'),
#  ({'ing': True,
#    'change': True,
#    'amp': True,
#    'friend': True,
#    'anymore': True,
#    'help': True},
#   'Negative'),
#  ({'eddieifft': True,
#    'kick': True,
#    'as': True,
#    'man': True,
#    'huge': True,
#    'melborne': True},
#   'Positive'),
#  ({'rave': True,
#    'rolling': True,
#    'star': True,
#    'sanctuary': True,
#    'mix': True,
#    'kick': True,
#    'as': True,
#    'ya': True,
#    'thanks': True,
#    'telling': True,
#    'felt': True,
#    'great': True},
#   'Negative'),
#  ({'tweeterdiva': True,
#    'easy': True,
#    'turn': True,
#    'keyboard': True,
#    'upside': True},
#   'Positive'),
#  ({'souljaboytellem': True,
#    'amp': True,
#    'drakkarnoid': True,
#    'bish': True,
#    'b': True,
#    'havin': True,
#    'u': True,
#    'itinerary': True,
#    'america': True,
#    'wanted': True,
#    'music': True,
#    'festival': True},
#   'Negative'),
#  ({'home': True,
#    'gal': True,
#    'office': True,
#    'laying': True,
#    'people': True,
#    'left': True,
#    'right': True,
#    'sad': True,
#    'situation': True},
#   'Negative'),
#  ({'yet': True,
#    'another': True,
#    'day': True,
#    'working': True,
#    'thru': True,
#    'weekend': True,
#    'suck': True},
#   'Negative'),
#  ({'morning': True,
#    'another': True,
#    'hot': True,
#    'day': True,
#    'im': True,
#    'bloody': True,
#    'work': True},
#   'Negative'),
#  ({'slightly': True,
#    'annoyed': True,
#    'tweetmygaming': True,
#    'mg': True,
#    'first': True,
#    'two': True,
#    'splinter': True,
#    'cell': True,
#    'sphinx': True,
#    'cursed': True,
#    'mummy': True,
#    'inventory': True},
#   'Negative'),
#  ({'davegray': True,
#    'used': True,
#    'favor': True,
#    'dogma': True,
#    'accidentally': True,
#    'ran': True,
#    'karma': True},
#   'Positive'),
#  ({'ctcash': True,
#    'buildingateam': True,
#    'diabetescure': True,
#    'chocolatetweet': True,
#    'thanks': True,
#    'spreading': True,
#    'word': True,
#    'diabetes': True,
#    'spain': True,
#    'http': True,
#    'bit': True,
#    'ly': True,
#    'ug': True},
#   'Positive'),
#  ({'soooo': True, 'hot': True, 'ac': True, 'working': True}, 'Negative'),
#  ({'kevin': True, 'smith': True, 'standup': True, 'town': True, 'im': True},
#   'Negative'),
#  ({'never': True, 'said': True, 'good': True, 'volleyball': True}, 'Positive'),
#  ({'hihack': True,
#    'dude': True,
#    'post': True,
#    'link': True,
#    'plz': True,
#    'remember': True,
#    'put': True,
#    'space': True,
#    'text': True,
#    'url': True},
#   'Positive'),
#  ({'ingridmusic': True,
#    'wait': True,
#    'new': True,
#    'record': True,
#    'go': True,
#    'girl': True},
#   'Positive'),
#  ({'zomg': True, 'show': True, 'epic': True}, 'Positive'),
#  ({'maybe': True,
#    'playing': True,
#    'pokemon': True,
#    'emerald': True,
#    'mlb': True,
#    'k': True,
#    'make': True,
#    'feel': True,
#    'bit': True,
#    'better': True},
#   'Negative'),
#  ({'natalieimcool': True,
#    'twhirling': True,
#    'pretty': True,
#    'cute': True,
#    'im': True,
#    'said': True,
#    'leave': True,
#    'firefox': True,
#    'behind': True,
#    'though': True,
#    'good': True},
#   'Negative'),
#  ({'bomseh': True,
#    'sigh': True,
#    'could': True,
#    'teach': True,
#    'technique': True,
#    'helpful': True,
#    'called': True,
#    'sleeping': True,
#    'foot': True,
#    'work': True,
#    'everywhere': True},
#   'Positive'),
#  ({'khallwalker': True,
#    'experience': True,
#    'show': True,
#    'sending': True,
#    'kid': True,
#    'partner': True,
#    'get': True,
#    'successful': True,
#    'alternative': True},
#   'Positive'),
#  ...]

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_data)

print(" Training Accuracy is:", round(classify.accuracy(classifier, train_data),2)*100)

print("Testing Accuracy is:", round(classify.accuracy(classifier, test_data),2)*100)

print(classifier.show_most_informative_features(10))
# Out:
#  Training Accuracy is: 86.0
# Testing Accuracy is: 77.0
# Most Informative Features
#                     iran = True           Negati : Positi =     91.7 : 1.0
#                  fawcett = True           Negati : Positi =     52.4 : 1.0
#              squarespace = True           Negati : Positi =     42.4 : 1.0
#                   farrah = True           Negati : Positi =     30.4 : 1.0
#               devastated = True           Negati : Positi =     27.0 : 1.0
#                    lvatt = True           Negati : Positi =     27.0 : 1.0
#                   boohoo = True           Negati : Positi =     26.3 : 1.0
#               condolence = True           Negati : Positi =     26.3 : 1.0
#                 hayfever = True           Negati : Positi =     25.7 : 1.0
#                    stiff = True           Negati : Positi =     25.7 : 1.0
# None

# %% [markdown]
# ### TFIDF for sentiment analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
vector = tfidf.fit_transform(data_cleaned['text'])
y = data_cleaned['Sentiment']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(vector,
                                                    y,
                                                    test_size=0.33,
                                                    random_state=42,
                                                    stratify = y)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression

# %%
def metrics(y_train,y_train_pred,y_test,y_test_pred):
  print("training accuracy = ",round(accuracy_score(y_train,y_train_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_train,y_train_pred,normalize = 'all')
  print(classification_report(y_train,y_train_pred))
  plt.show()

  print("testing accuracy = ",round(accuracy_score(y_test,y_test_pred),2)*100)
  ConfusionMatrixDisplay.from_predictions(y_test,y_test_pred,normalize = 'all')
  print(classification_report(y_test,y_test_pred))
  plt.show()

# %% [markdown]
# ### Multinomial NB

# %%
NB = MultinomialNB()
NB.fit(X_train,y_train)
y_train_pred = NB.predict(X_train)
y_test_pred = NB.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  85.0
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85    166545
#            1       0.87      0.82      0.85    166546
#
#     accuracy                           0.85    333091
#    macro avg       0.85      0.85      0.85    333091
# weighted avg       0.85      0.85      0.85    333091
# testing accuracy =  76.0
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77     82031
#            1       0.78      0.73      0.75     82030
#
#     accuracy                           0.76    164061
#    macro avg       0.76      0.76      0.76    164061
# weighted avg       0.76      0.76      0.76    164061

# %% [markdown]
# ### Linear SVC

# %%
svc = LinearSVC()
svc.fit(X_train,y_train)
y_train_pred = svc.predict(X_train)
y_test_pred = svc.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  90.0
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90    166545
#            1       0.90      0.90      0.90    166546
#
#     accuracy                           0.90    333091
#    macro avg       0.90      0.90      0.90    333091
# weighted avg       0.90      0.90      0.90    333091
# testing accuracy =  77.0
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77     82031
#            1       0.76      0.78      0.77     82030
#
#     accuracy                           0.77    164061
#    macro avg       0.77      0.77      0.77    164061
# weighted avg       0.77      0.77      0.77    164061

# %% [markdown]
# ### Logistic regression

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
metrics(y_train,y_train_pred,y_test,y_test_pred)
# Out:
# training accuracy =  83.0
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82    166545
#            1       0.82      0.84      0.83    166546
#
#     accuracy                           0.83    333091
#    macro avg       0.83      0.83      0.83    333091
# weighted avg       0.83      0.83      0.83    333091
# testing accuracy =  78.0
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77     82031
#            1       0.77      0.80      0.78     82030
#
#     accuracy                           0.78    164061
#    macro avg       0.78      0.78      0.78    164061
# weighted avg       0.78      0.78      0.78    164061

# %% [markdown]
# ## Conclusion
#
# |Model|Training Accuracy|Testing Accuracy|
# |---|---|---|
# |Naive Bayes|86%|76%|
# |Multinomial NB| 85%|76%|
# |linear SVC|90%|77%|
# |Logistic|83%|78%|

# %% [markdown]
# We see that Logistic regression model performs best with least overfitting as compared to other models and has better performance in testing dataset as well
